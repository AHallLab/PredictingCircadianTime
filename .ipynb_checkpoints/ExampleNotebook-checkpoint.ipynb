# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import seaborn as sn
import math
import tqdm
import gc
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler, normalize
import CorrelationMetrics
from scipy.stats import ks_2samp
from functools import reduce
import random
import os
from numpy.linalg import norm

# %%
val_errors1 = []
test_errors1 = []

N_GENES = 50
SEED = 0
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# Load training, validation, test datasets

df = pd.read_csv('Data//X_train_raw.csv').T
df_valid = pd.read_csv('Data//X_valid_raw.csv').T
df_test = pd.concat((pd.read_csv('Data//X_test_raw_A.txt').T, pd.read_csv('Data//X_test_raw_B.txt').T)).iloc[[0, 1, 2, 4, 5], :]
rach_clusters = pd.read_csv('Data//X_train_clusters.csv')
Y_data = df.iloc[1:, -1].astype('float64')
Y_copy = Y_data
Y_valid_data = df_valid.iloc[1:, -1].astype('float64')
Y_valid_copy = Y_valid_data

# Select genes present in all three datasets

common_IDs = reduce(np.intersect1d, (df.iloc[0, :-1].values, df_valid.iloc[0, :-1].values, df_test.iloc[0, :].values))

idx = np.where(df.iloc[0, :].isin(common_IDs))[0]
df = df.iloc[:, idx]
idx_valid = np.where(df_valid.iloc[0, :].isin(common_IDs))[0]
df_valid = df_valid.iloc[:, idx_valid]
idx_test = np.where(df_test.iloc[0, :].isin(common_IDs))[0]
df_test = df_test.iloc[:, idx_test]

X_data = df.iloc[1:, :].astype('float64')
X_ID = df.iloc[0, :]
X_valid_data = df_valid.iloc[1:, :].astype('float64')
X_valid_ID = df_valid.iloc[0, :]
X_test_data = df_test.iloc[1:, :].astype('float64')
X_test_ID = df_test.iloc[0, :]

X_ID1 = np.argsort(X_ID)
X_ID = X_ID.iloc[X_ID1]
X_data = X_data.iloc[:, X_ID1]
X_data.columns = X_ID
X_ID1 = np.argsort(X_valid_ID)
X_valid_ID = X_valid_ID.iloc[X_ID1]
X_valid_data = X_valid_data.iloc[:, X_ID1]
X_valid_data.columns = X_valid_ID
X_ID1 = np.argsort(X_test_ID)
X_test_ID = X_test_ID.iloc[X_ID1]
X_test_data = X_test_data.iloc[:, X_ID1]
X_test_data.columns = X_test_ID

# %%
# Variance threshold
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold()
selector.fit(X_data)
var_idx = selector.variances_ > 8
X_data = X_data.iloc[:, var_idx]
X_ID = X_ID.iloc[var_idx]
X_valid_data = X_valid_data.iloc[:, var_idx]
X_valid_ID = X_valid_ID.iloc[var_idx]
X_test_data = X_test_data.iloc[:, var_idx]
X_test_ID = X_test_ID.iloc[var_idx]

X_data.reset_index(inplace=True, drop=True)
X_valid_data.reset_index(inplace=True, drop=True)
X_test_data.reset_index(inplace=True, drop=True)

X_ID.reset_index(inplace=True, drop=True)
X_valid_ID.reset_index(inplace=True, drop=True)
X_test_ID.reset_index(inplace=True, drop=True)

del df
gc.collect()

n_folds = Y_data.shape[0]
folds = KFold(n_splits=n_folds, random_state=SEED)

# Transform time onto the unit circle to enable cyclical loss function

y_cos = -np.cos((2 * np.pi * Y_data.astype('float64') / 24)+(np.pi/2))
y_sin = np.sin((2 * np.pi * Y_data.astype('float64') / 24)+(np.pi/2))

Y_valid_cos = -np.cos((2 * np.pi * Y_valid_data.astype('float64') / 24)+(np.pi/2))
Y_valid_sin = np.sin((2 * np.pi * Y_valid_data.astype('float64') / 24)+(np.pi/2))

Y_data = np.concatenate((y_cos.values.reshape(-1, 1), y_sin.values.reshape(-1, 1)), axis=1)
Y_valid_data = np.concatenate((Y_valid_cos.values.reshape(-1, 1), Y_valid_sin.values.reshape(-1, 1)), axis=1)
# Out:
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
# Define cyclical loss function and metric

def cyclical_loss(y_true, y_pred):
    error = 0
    for i in range(y_pred.shape[0]):
        error += np.arccos((y_true[i, :] @ y_pred[i, :]) / (norm(y_true[i, :]) * norm(y_pred[i, :])))
    return error

def custom_loss(y_true, y_pred):
    return tf.reduce_mean((tf.math.acos(tf.matmul(y_true, tf.transpose(y_pred)) / ((tf.norm(y_true) * tf.norm(y_pred)) + tf.keras.backend.epsilon()))**2))

adam = Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, amsgrad=False)


def larger_model():
    # Create model
    model = Sequential()
    model.add(Dense(32, kernel_initializer='normal', activation='relu'))
    model.add(Dense(128, kernel_initializer='normal', activation='relu'))
    model.add(Dense(512, kernel_initializer='normal', activation='relu'))
    model.add(Dense(2, kernel_initializer='normal'))
    # Compile model
    model.compile(loss=custom_loss, optimizer=adam)
    return model

# Initialise error and prediction arrays
error = 0
all_preds = np.zeros((Y_data.shape[0], 2))
all_valid_preds = np.zeros((Y_valid_data.shape[0], 2))
early_stop = EarlyStopping(patience=50, restore_best_weights=True, monitor='val_loss', mode='min')

# %%
# Score all genes based on rhythmic metrics
auto_indices, auto_clock_genes, auto_scores = CorrelationMetrics.get_autocorrelated_genes(X_data, X_ID)
auto_scores = np.abs(np.array(auto_scores))

cross_indices, cross_clock_genes, cross_scores = CorrelationMetrics.cross_corr(X_data, Y_copy, X_ID)
cross_scores = np.abs(np.array(cross_scores))

scores = np.concatenate((auto_scores.reshape(-1, 1), cross_scores.reshape(-1, 1)), axis=1)

# Aggregate scores and select highest scoring genes

auto_scores = np.argsort(np.mean(scores, axis=1))
scores1 = np.mean(scores, axis=1)
scores2 = np.concatenate((X_data.columns.values.reshape(-1, 1), scores1.reshape(-1, 1)), axis=1)
auto_indices = auto_scores[-N_GENES*50:]
auto_clock_genes = np.array(auto_clock_genes)
auto_clock_genes = auto_clock_genes[auto_indices]
auto_scores1 = scores1[auto_indices]

idx = np.where(X_ID.isin(auto_clock_genes))[0]
X_data = X_data.iloc[:, idx]
scores2 = scores2[idx]
idx_valid = np.where(X_valid_ID.isin(auto_clock_genes))[0]
X_valid_data = X_valid_data.iloc[:, idx_valid]
idx_test = np.where(X_test_ID.isin(auto_clock_genes))[0]
X_test_data = X_test_data.iloc[:, idx_test]

X_ID = X_ID.iloc[idx]
X_valid_ID = X_valid_ID.iloc[idx_valid]
X_test_ID = X_test_ID.iloc[idx_test]

scores = []
pvalues = []

# Remove genes whose distribution is different between training and validation dataset

for i in range(X_data.shape[1]):
    l = ks_2samp(X_data.iloc[:, i], X_valid_data.iloc[:, i])
    scores.append(i)
    pvalues.append(l.pvalue)

pvalues_idx = np.argsort(pvalues)
scores = pvalues_idx[(pvalues_idx.shape[0]-30*N_GENES):]

similar_genes = auto_clock_genes[scores]
X_data = X_data.iloc[:, scores]
scores2 = scores2[scores]
X_ID = X_ID.iloc[scores]
X_valid_data = X_valid_data.iloc[:, scores]
X_test_data = X_test_data.iloc[:, scores]
auto_scores1 = auto_scores1[scores]

Y_copy_res = np.array([0, 4, 8, 12, 16, 20, 0, 4, 8, 12, 16, 20])

X_ID2 = X_data.columns.values

# Scale expression data before entering neural network

scaler = MinMaxScaler()
scaler.fit(X_data)
X_data = scaler.transform(X_data)
X_valid_data = scaler.transform(X_valid_data)
X_test_data = scaler.transform(X_test_data)

X_data = pd.DataFrame(data=X_data, columns=X_ID2)
X_valid_data = pd.DataFrame(data=X_valid_data, columns=X_ID2)
X_test_data = pd.DataFrame(data=X_test_data, columns=X_ID2)

# Remove genes whose expression level is different between training and validation

column_max = np.max(X_valid_data.values, axis=0)
column_min = np.min(X_valid_data.values, axis=0)
column_idx = column_max < 1.4
column_idx1 = column_min > -0.2
column_idx = np.logical_and(column_idx, column_idx1)
X_data = X_data.iloc[:, column_idx]
scores2 = scores2[column_idx]
X_ID = X_ID.iloc[column_idx]
X_valid_data = X_valid_data.iloc[:, column_idx]
X_test_data = X_test_data.iloc[:, column_idx]
auto_scores1 = auto_scores1[column_idx]
# Out:
# 100%|██████████| 9664/9664 [00:05<00:00, 1809.39it/s]
# 100%|██████████| 9664/9664 [00:06<00:00, 1523.49it/s]

# %%
# Primitive method of selecting genes belonging from diverse clusters, sequential method included in separate .py file
P = pd.DataFrame(data=scores2, columns=['transcript', 'score'])
L = pd.merge(P, rach_clusters, how='left', left_on='transcript', right_on='transcript')

L.fillna(value='None', inplace=True)
print(L['moduleColor'].value_counts())

colours = L['moduleColor'].unique()

results = {'idx': [], 'train_error': [], 'val_error': [], 'test_error': []}
results1 = []
idx_perm = []
graph_res = []

n_genes = 0
i = 0
counter = 0

keep = []

for i in range(colours.shape[0]):
    colour = colours[i]
    genes = L.loc[L['moduleColor'] == colour]
    genes.sort_values(by='score', inplace=True, ascending=False)
    keep.append(genes.index.values[:8])

keep = np.concatenate(keep)
L = L.iloc[keep, :]
X_data = X_data.iloc[:, keep]
X_valid_data = X_valid_data.iloc[:, keep]
X_test_data = X_test_data.iloc[:, keep]

L.reset_index(drop=True, inplace=True)


i = 0

idx = [3, 12, 18, 29, 38, 44, 52, 58, 64, 8, 17, 25, 34, 49, 62]

X_data = X_data.iloc[:, idx]
X_valid_data = X_valid_data.iloc[:, idx]
X_test_data = X_test_data.iloc[:, idx]

X_data = X_data.values
X_valid_data =X_valid_data.values
X_test_data = X_test_data.values
#
valid_preds = []
test_preds = []

# K-fold cross validation fit model on train, predict on valid and test

for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_data, Y_data)):
    X_train, Y_train = X_data[train_idx], Y_data[train_idx]  # Define training data for this iteration
    X_valid, Y_valid = X_data[valid_idx], Y_data[valid_idx]

    model = larger_model()
    model.fit(X_train.astype('float64'), Y_train.astype('float64'), validation_data=(X_valid.astype('float64'), Y_valid.astype('float64')),
              batch_size=2, epochs=5000, callbacks=[early_stop])  # Fit the model on the training data
    preds = normalize(model.predict(X_valid))  # Predict on the validation data
    all_preds[valid_idx] = normalize(model.predict(X_valid))
    all_valid_preds += (normalize(model.predict(X_valid_data)) / n_folds)
    valid_preds.append(normalize(model.predict(X_valid_data)))
    test_preds.append(normalize(model.predict(X_test_data)))
    error += cyclical_loss(Y_valid.astype('float64'), preds.astype('float64'))  # Evaluate the predictions
    print(cyclical_loss(Y_valid.astype('float64'), preds.astype('float64')) / Y_valid.shape[0])
# Out:
# turquoise    208
# yellow       196
# blue         168
# None         156
# brown        143
# red          104
# green         99
# pink          54
# black         40
# Name: moduleColor, dtype: int64
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\colmer\AppData\Local\Continuum\anaconda3\envs\SeedGerm\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Train on 11 samples, validate on 1 samples
# Epoch 1/5000
# 11/11 [==============================] - ETA: 2s - loss: 2.948 - 1s 62ms/sample - loss: 2.6163 - val_loss: 1.6968
# Epoch 2/5000
# 11/11 [==============================] - ETA: 0s - loss: 3.628 - 0s 2ms/sample - loss: 2.6711 - val_loss: 1.6475
# Epoch 3/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.533 - 0s 2ms/sample - loss: 2.6157 - val_loss: 1.4957
# Epoch 4/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.751 - 0s 1ms/sample - loss: 2.6081 - val_loss: 1.5453
# Epoch 5/5000
# 11/11 [==============================] - ETA: 0s - loss: 3.316 - 0s 2ms/sample - loss: 2.6570 - val_loss: 1.6368
# Epoch 6/5000
# 11/11 [==============================] - ETA: 0s - loss: 3.557 - 0s 2ms/sample - loss: 2.5823 - val_loss: 1.7155
# Epoch 7/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.782 - 0s 2ms/sample - loss: 2.7974 - val_loss: 1.8009
# Epoch 8/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.931 - 0s 2ms/sample - loss: 2.4360 - val_loss: 1.5360
# Epoch 9/5000
# 11/11 [==============================] - ETA: 0s - loss: 3.040 - 0s 2ms/sample - loss: 2.5498 - val_loss: 1.4022
# Epoch 10/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.500 - 0s 2ms/sample - loss: 2.5809 - val_loss: 1.0689
# Epoch 11/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.381 - 0s 2ms/sample - loss: 2.5030 - val_loss: 0.7358
# Epoch 12/5000
# 11/11 [==============================] - ETA: 0s - loss: 3.021 - 0s 2ms/sample - loss: 2.3820 - val_loss: 0.4869
# Epoch 13/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.368 - 0s 2ms/sample - loss: 2.2284 - val_loss: 0.2234
# Epoch 14/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.791 - 0s 2ms/sample - loss: 2.3814 - val_loss: 0.0652
# Epoch 15/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.495 - 0s 2ms/sample - loss: 2.1313 - val_loss: 0.0020
# Epoch 16/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.958 - 0s 2ms/sample - loss: 2.0180 - val_loss: 0.0063
# Epoch 17/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.620 - 0s 2ms/sample - loss: 2.0475 - val_loss: 0.0362
# Epoch 18/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.879 - 0s 2ms/sample - loss: 1.5826 - val_loss: 0.1026
# Epoch 19/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.914 - 0s 2ms/sample - loss: 2.0331 - val_loss: 0.3052
# Epoch 20/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.683 - 0s 2ms/sample - loss: 2.2518 - val_loss: 0.5895
# Epoch 21/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.427 - 0s 2ms/sample - loss: 1.6911 - val_loss: 0.9481
# Epoch 22/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.709 - 0s 1ms/sample - loss: 2.1318 - val_loss: 1.1642
# Epoch 23/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.876 - 0s 2ms/sample - loss: 1.8271 - val_loss: 1.2192
# Epoch 24/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.922 - 0s 2ms/sample - loss: 1.9965 - val_loss: 1.2550
# Epoch 25/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.704 - 0s 2ms/sample - loss: 2.1914 - val_loss: 1.2813
# Epoch 26/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.172 - 0s 2ms/sample - loss: 1.7445 - val_loss: 1.2714
# Epoch 27/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.507 - 0s 1ms/sample - loss: 1.7441 - val_loss: 1.1833
# Epoch 28/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.083 - 0s 1ms/sample - loss: 1.7699 - val_loss: 1.1186
# Epoch 29/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.849 - 0s 1ms/sample - loss: 1.5062 - val_loss: 0.7885
# Epoch 30/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.631 - 0s 1ms/sample - loss: 2.0066 - val_loss: 0.5243
# Epoch 31/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.741 - 0s 1ms/sample - loss: 2.0726 - val_loss: 0.4377
# Epoch 32/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.712 - 0s 1ms/sample - loss: 1.5221 - val_loss: 0.4693
# Epoch 33/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.581 - 0s 1ms/sample - loss: 2.1796 - val_loss: 0.3116
# Epoch 34/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.551 - 0s 2ms/sample - loss: 2.1939 - val_loss: 0.2201
# Epoch 35/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.329 - 0s 1ms/sample - loss: 1.4533 - val_loss: 0.2338
# Epoch 36/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.475 - 0s 1ms/sample - loss: 1.7023 - val_loss: 0.2120
# Epoch 37/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.238 - 0s 1ms/sample - loss: 1.5217 - val_loss: 0.2501
# Epoch 38/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.679 - 0s 1ms/sample - loss: 1.8690 - val_loss: 0.2365
# Epoch 39/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.722 - 0s 1ms/sample - loss: 1.8076 - val_loss: 0.1887
# Epoch 40/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.557 - 0s 1ms/sample - loss: 1.8245 - val_loss: 0.1279
# Epoch 41/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.198 - 0s 1ms/sample - loss: 1.8216 - val_loss: 0.1127
# Epoch 42/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.190 - 0s 1ms/sample - loss: 2.0573 - val_loss: 0.1386
# Epoch 43/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.661 - 0s 1ms/sample - loss: 2.1627 - val_loss: 0.1154
# Epoch 44/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.450 - 0s 1ms/sample - loss: 1.8988 - val_loss: 0.0209
# Epoch 45/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.148 - 0s 1ms/sample - loss: 1.4314 - val_loss: 0.0071
# Epoch 46/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.193 - 0s 2ms/sample - loss: 1.7866 - val_loss: 2.5118e-04
# Epoch 47/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.284 - 0s 1ms/sample - loss: 1.5131 - val_loss: 3.0185e-04
# Epoch 48/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.347 - 0s 1ms/sample - loss: 1.9435 - val_loss: 0.0018
# Epoch 49/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.598 - 0s 1ms/sample - loss: 1.5355 - val_loss: 0.0083
# Epoch 50/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.486 - 0s 1ms/sample - loss: 1.6183 - val_loss: 0.0014
# Epoch 51/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.424 - 0s 1ms/sample - loss: 1.3523 - val_loss: 0.0016
# Epoch 52/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.978 - 0s 1ms/sample - loss: 1.9069 - val_loss: 0.0056
# Epoch 53/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.455 - 0s 2ms/sample - loss: 1.7707 - val_loss: 0.0061
# Epoch 54/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.621 - 0s 2ms/sample - loss: 1.4345 - val_loss: 9.9143e-04
# Epoch 55/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.707 - 0s 1ms/sample - loss: 1.5396 - val_loss: 0.0068
# Epoch 56/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.102 - 0s 1ms/sample - loss: 1.4857 - val_loss: 0.0186
# Epoch 57/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.939 - 0s 1ms/sample - loss: 1.6645 - val_loss: 0.0140
# Epoch 58/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.397 - 0s 2ms/sample - loss: 1.7353 - val_loss: 9.0272e-04
# Epoch 59/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.562 - 0s 1ms/sample - loss: 2.0258 - val_loss: 3.1532e-04
# Epoch 60/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.434 - 0s 1ms/sample - loss: 1.5652 - val_loss: 6.2815e-04
# Epoch 61/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.064 - 0s 1ms/sample - loss: 1.7133 - val_loss: 0.0057
# Epoch 62/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.450 - 0s 1ms/sample - loss: 1.7777 - val_loss: 0.0012
# Epoch 63/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.738 - 0s 2ms/sample - loss: 1.9084 - val_loss: 7.6056e-05
# Epoch 64/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.336 - 0s 2ms/sample - loss: 1.9109 - val_loss: 0.0028
# Epoch 65/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.203 - 0s 1ms/sample - loss: 1.8110 - val_loss: 0.0116
# Epoch 66/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.056 - 0s 1ms/sample - loss: 1.6831 - val_loss: 0.0392
# Epoch 67/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.112 - 0s 1ms/sample - loss: 1.8564 - val_loss: 0.0600
# Epoch 68/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.563 - 0s 1ms/sample - loss: 1.5838 - val_loss: 0.0826
# Epoch 69/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.176 - 0s 1ms/sample - loss: 1.6559 - val_loss: 0.1247
# Epoch 70/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.331 - 0s 1ms/sample - loss: 1.7383 - val_loss: 0.1157
# Epoch 71/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.743 - 0s 1ms/sample - loss: 1.6246 - val_loss: 0.0575
# Epoch 72/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.756 - 0s 1ms/sample - loss: 1.4563 - val_loss: 0.0279
# Epoch 73/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.720 - 0s 1ms/sample - loss: 1.9580 - val_loss: 0.0128
# Epoch 74/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.645 - 0s 1ms/sample - loss: 1.8297 - val_loss: 0.0139
# Epoch 75/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.154 - 0s 1ms/sample - loss: 1.6998 - val_loss: 0.0227
# Epoch 76/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.063 - 0s 1ms/sample - loss: 1.6253 - val_loss: 0.0198
# Epoch 77/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.353 - 0s 1ms/sample - loss: 1.7532 - val_loss: 0.0212
# Epoch 78/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.572 - 0s 1ms/sample - loss: 1.8086 - val_loss: 0.0182
# Epoch 79/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.346 - 0s 1ms/sample - loss: 2.0600 - val_loss: 0.0232
# Epoch 80/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.382 - 0s 1ms/sample - loss: 1.6942 - val_loss: 0.0397
# Epoch 81/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.265 - 0s 1ms/sample - loss: 1.6125 - val_loss: 0.0646
# Epoch 82/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.209 - 0s 1ms/sample - loss: 2.0850 - val_loss: 0.0548
# Epoch 83/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.921 - 0s 1ms/sample - loss: 1.9105 - val_loss: 0.0399
# Epoch 84/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.743 - 0s 1ms/sample - loss: 1.9270 - val_loss: 0.0416
# Epoch 85/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.550 - 0s 1ms/sample - loss: 1.9394 - val_loss: 0.0461
# Epoch 86/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.578 - 0s 1ms/sample - loss: 1.6374 - val_loss: 0.0331
# Epoch 87/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.322 - 0s 1ms/sample - loss: 1.8664 - val_loss: 0.0296
# Epoch 88/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.123 - 0s 1ms/sample - loss: 1.4875 - val_loss: 0.0153
# Epoch 89/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.324 - 0s 1ms/sample - loss: 1.8277 - val_loss: 4.3847e-04
# Epoch 90/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.134 - 0s 1ms/sample - loss: 1.7472 - val_loss: 9.9608e-04
# Epoch 91/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.330 - 0s 1ms/sample - loss: 1.6990 - val_loss: 0.0041
# Epoch 92/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.730 - 0s 1ms/sample - loss: 1.7889 - val_loss: 0.0039
# Epoch 93/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.374 - 0s 1ms/sample - loss: 1.2274 - val_loss: 0.0049
# Epoch 94/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.131 - 0s 1ms/sample - loss: 1.8099 - val_loss: 0.0041
# Epoch 95/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.369 - 0s 1ms/sample - loss: 1.9905 - val_loss: 0.0065
# Epoch 96/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.357 - 0s 1ms/sample - loss: 1.8231 - val_loss: 0.0106
# Epoch 97/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.046 - 0s 2ms/sample - loss: 1.9008 - val_loss: 0.0075
# Epoch 98/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.310 - 0s 1ms/sample - loss: 2.3107 - val_loss: 0.0121
# Epoch 99/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.741 - 0s 1ms/sample - loss: 1.8342 - val_loss: 0.0161
# Epoch 100/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.516 - 0s 2ms/sample - loss: 1.4329 - val_loss: 0.0029
# Epoch 101/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.437 - 0s 1ms/sample - loss: 1.9365 - val_loss: 0.0017
# Epoch 102/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.713 - 0s 1ms/sample - loss: 1.6904 - val_loss: 1.4568e-04
# Epoch 103/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.145 - 0s 2ms/sample - loss: 2.1350 - val_loss: 0.0028
# Epoch 104/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.337 - 0s 2ms/sample - loss: 1.7199 - val_loss: 6.5804e-05
# Epoch 105/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.450 - 0s 1ms/sample - loss: 1.5796 - val_loss: 0.0034
# Epoch 106/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.934 - 0s 1ms/sample - loss: 1.7936 - val_loss: 0.0057
# Epoch 107/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.393 - 0s 1ms/sample - loss: 1.4733 - val_loss: 0.0052
# Epoch 108/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.375 - 0s 1ms/sample - loss: 1.8405 - val_loss: 0.0040
# Epoch 109/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.714 - 0s 1ms/sample - loss: 1.8373 - val_loss: 0.0033
# Epoch 110/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.411 - 0s 1ms/sample - loss: 1.4853 - val_loss: 9.6353e-04
# Epoch 111/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.706 - 0s 1ms/sample - loss: 1.6429 - val_loss: 3.6478e-05
# Epoch 112/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.498 - 0s 1ms/sample - loss: 1.9137 - val_loss: 6.6367e-04
# Epoch 113/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.227 - 0s 1ms/sample - loss: 2.0790 - val_loss: 0.0130
# Epoch 114/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.697 - 0s 2ms/sample - loss: 2.0321 - val_loss: 0.0188
# Epoch 115/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.454 - 0s 2ms/sample - loss: 1.2364 - val_loss: 0.0164
# Epoch 116/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.809 - 0s 1ms/sample - loss: 1.9200 - val_loss: 0.0111
# Epoch 117/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.708 - 0s 1ms/sample - loss: 1.5652 - val_loss: 0.0079
# Epoch 118/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.657 - 0s 2ms/sample - loss: 1.9907 - val_loss: 0.0122
# Epoch 119/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.729 - 0s 1ms/sample - loss: 2.1415 - val_loss: 6.2230e-04
# Epoch 120/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.720 - 0s 1ms/sample - loss: 1.8616 - val_loss: 8.7029e-04
# Epoch 121/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.328 - 0s 1ms/sample - loss: 1.8421 - val_loss: 0.0016
# Epoch 122/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.712 - 0s 1ms/sample - loss: 2.0748 - val_loss: 0.0125
# Epoch 123/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.139 - 0s 1ms/sample - loss: 1.5889 - val_loss: 0.0200
# Epoch 124/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.448 - 0s 2ms/sample - loss: 1.7149 - val_loss: 0.0147
# Epoch 125/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.735 - 0s 1ms/sample - loss: 2.1596 - val_loss: 0.0081
# Epoch 126/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.328 - 0s 1ms/sample - loss: 1.9188 - val_loss: 0.0082
# Epoch 127/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.114 - 0s 1ms/sample - loss: 1.4884 - val_loss: 0.0075
# Epoch 128/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.435 - 0s 2ms/sample - loss: 1.6964 - val_loss: 0.0160
# Epoch 129/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.133 - 0s 1ms/sample - loss: 1.6332 - val_loss: 0.0376
# Epoch 130/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.010 - 0s 2ms/sample - loss: 1.9050 - val_loss: 0.0575
# Epoch 131/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.347 - 0s 1ms/sample - loss: 1.8841 - val_loss: 0.0690
# Epoch 132/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.206 - 0s 1ms/sample - loss: 1.7741 - val_loss: 0.0594
# Epoch 133/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.220 - 0s 1ms/sample - loss: 2.1494 - val_loss: 0.0544
# Epoch 134/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.114 - 0s 1ms/sample - loss: 1.8241 - val_loss: 0.0552
# Epoch 135/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.363 - 0s 1ms/sample - loss: 1.9474 - val_loss: 0.0558
# Epoch 136/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.460 - 0s 1ms/sample - loss: 1.5433 - val_loss: 0.0545
# Epoch 137/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.679 - 0s 1ms/sample - loss: 1.6675 - val_loss: 0.0180
# Epoch 138/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.404 - 0s 1ms/sample - loss: 1.7389 - val_loss: 0.0059
# Epoch 139/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.349 - 0s 2ms/sample - loss: 1.6839 - val_loss: 0.0076
# Epoch 140/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.333 - 0s 1ms/sample - loss: 1.7266 - val_loss: 0.0077
# Epoch 141/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.740 - 0s 1ms/sample - loss: 1.9096 - val_loss: 0.0124
# Epoch 142/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.423 - 0s 1ms/sample - loss: 1.9119 - val_loss: 0.0226
# Epoch 143/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.730 - 0s 1ms/sample - loss: 1.8666 - val_loss: 0.0430
# Epoch 144/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.507 - 0s 1ms/sample - loss: 1.7154 - val_loss: 0.0781
# Epoch 145/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.401 - 0s 1ms/sample - loss: 1.6873 - val_loss: 0.0872
# Epoch 146/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.469 - 0s 1ms/sample - loss: 1.6412 - val_loss: 0.0702
# Epoch 147/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.126 - 0s 1ms/sample - loss: 1.6708 - val_loss: 0.0659
# Epoch 148/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.550 - 0s 1ms/sample - loss: 1.4034 - val_loss: 0.0631
# Epoch 149/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.342 - 0s 1ms/sample - loss: 1.9339 - val_loss: 0.0602
# Epoch 150/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.613 - 0s 1ms/sample - loss: 1.4877 - val_loss: 0.0499
# Epoch 151/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.549 - 0s 2ms/sample - loss: 1.6214 - val_loss: 0.0458
# Epoch 152/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.101 - 0s 1ms/sample - loss: 1.4567 - val_loss: 0.0296
# Epoch 153/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.466 - 0s 1ms/sample - loss: 1.6447 - val_loss: 0.0255
# Epoch 154/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.513 - 0s 1ms/sample - loss: 1.8394 - val_loss: 0.0157
# Epoch 155/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.309 - 0s 1ms/sample - loss: 1.4158 - val_loss: 0.0104
# Epoch 156/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.314 - 0s 1ms/sample - loss: 1.7455 - val_loss: 0.0106
# Epoch 157/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.176 - 0s 1ms/sample - loss: 1.8154 - val_loss: 0.0094
# Epoch 158/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.354 - 0s 1ms/sample - loss: 1.8393 - val_loss: 0.0027
# Epoch 159/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.114 - 0s 1ms/sample - loss: 1.6656 - val_loss: 6.3420e-05
# Epoch 160/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.400 - 0s 1ms/sample - loss: 1.3763 - val_loss: 0.0080
# Epoch 161/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.320 - 0s 1ms/sample - loss: 1.8052 - val_loss: 0.0105
# 0.0007017960827119697
# Train on 11 samples, validate on 1 samples
# Epoch 1/5000
# 11/11 [==============================] - ETA: 1s - loss: 3.160 - 0s 41ms/sample - loss: 2.5798 - val_loss: 0.5181
# Epoch 2/5000
# 11/11 [==============================] - ETA: 0s - loss: 3.855 - 0s 2ms/sample - loss: 2.6251 - val_loss: 0.3061
# Epoch 3/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.484 - 0s 2ms/sample - loss: 2.7151 - val_loss: 0.2049
# Epoch 4/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.737 - 0s 2ms/sample - loss: 2.5697 - val_loss: 0.1170
# Epoch 5/5000
# 11/11 [==============================] - ETA: 0s - loss: 3.275 - 0s 2ms/sample - loss: 2.9126 - val_loss: 0.0512
# Epoch 6/5000
# 11/11 [==============================] - ETA: 0s - loss: 3.013 - 0s 2ms/sample - loss: 2.2082 - val_loss: 0.0089
# Epoch 7/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.597 - 0s 1ms/sample - loss: 2.4771 - val_loss: 0.0059
# Epoch 8/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.914 - 0s 1ms/sample - loss: 1.9849 - val_loss: 0.5010
# Epoch 9/5000
# 11/11 [==============================] - ETA: 0s - loss: 3.786 - 0s 1ms/sample - loss: 2.4814 - val_loss: 1.1574
# Epoch 10/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.324 - 0s 1ms/sample - loss: 1.8969 - val_loss: 1.8666
# Epoch 11/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.631 - 0s 1ms/sample - loss: 2.1997 - val_loss: 2.4036
# Epoch 12/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.920 - 0s 1ms/sample - loss: 1.8621 - val_loss: 2.2316
# Epoch 13/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.449 - 0s 1ms/sample - loss: 1.6089 - val_loss: 2.0201
# Epoch 14/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.827 - 0s 1ms/sample - loss: 2.0923 - val_loss: 2.3735
# Epoch 15/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.435 - 0s 1ms/sample - loss: 1.8429 - val_loss: 2.4093
# Epoch 16/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.264 - 0s 1ms/sample - loss: 1.8006 - val_loss: 2.0013
# Epoch 17/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.853 - 0s 1ms/sample - loss: 1.7350 - val_loss: 1.6946
# Epoch 18/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.397 - 0s 1ms/sample - loss: 1.5100 - val_loss: 1.4324
# Epoch 19/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.543 - 0s 1ms/sample - loss: 2.0132 - val_loss: 1.2042
# Epoch 20/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.659 - 0s 1ms/sample - loss: 2.2541 - val_loss: 1.1146
# Epoch 21/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.323 - 0s 2ms/sample - loss: 1.5360 - val_loss: 0.9961
# Epoch 22/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.759 - 0s 1ms/sample - loss: 2.0181 - val_loss: 0.9243
# Epoch 23/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.245 - 0s 1ms/sample - loss: 1.6759 - val_loss: 0.8970
# Epoch 24/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.559 - 0s 1ms/sample - loss: 2.0209 - val_loss: 0.8534
# Epoch 25/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.703 - 0s 1ms/sample - loss: 2.1786 - val_loss: 0.8419
# Epoch 26/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.099 - 0s 1ms/sample - loss: 1.8703 - val_loss: 0.7523
# Epoch 27/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.350 - 0s 1ms/sample - loss: 1.8047 - val_loss: 0.6116
# Epoch 28/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.295 - 0s 1ms/sample - loss: 1.7189 - val_loss: 0.4558
# Epoch 29/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.199 - 0s 1ms/sample - loss: 1.3618 - val_loss: 0.2837
# Epoch 30/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.202 - 0s 2ms/sample - loss: 1.8494 - val_loss: 0.2287
# Epoch 31/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.459 - 0s 2ms/sample - loss: 2.1200 - val_loss: 0.2352
# Epoch 32/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.596 - 0s 1ms/sample - loss: 1.3614 - val_loss: 0.2627
# Epoch 33/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.722 - 0s 1ms/sample - loss: 2.1837 - val_loss: 0.2388
# Epoch 34/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.725 - 0s 1ms/sample - loss: 2.1820 - val_loss: 0.2329
# Epoch 35/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.513 - 0s 1ms/sample - loss: 1.4435 - val_loss: 0.1944
# Epoch 36/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.369 - 0s 1ms/sample - loss: 1.5651 - val_loss: 0.1784
# Epoch 37/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.243 - 0s 1ms/sample - loss: 1.3934 - val_loss: 0.1882
# Epoch 38/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.106 - 0s 1ms/sample - loss: 1.6869 - val_loss: 0.1988
# Epoch 39/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.742 - 0s 1ms/sample - loss: 1.6615 - val_loss: 0.1887
# Epoch 40/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.727 - 0s 1ms/sample - loss: 1.7972 - val_loss: 0.1828
# Epoch 41/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.524 - 0s 1ms/sample - loss: 1.8363 - val_loss: 0.1816
# Epoch 42/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.211 - 0s 1ms/sample - loss: 2.0457 - val_loss: 0.2064
# Epoch 43/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.148 - 0s 2ms/sample - loss: 2.0602 - val_loss: 0.2031
# Epoch 44/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.346 - 0s 1ms/sample - loss: 1.7233 - val_loss: 0.1804
# Epoch 45/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.102 - 0s 1ms/sample - loss: 1.5535 - val_loss: 0.1618
# Epoch 46/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.260 - 0s 1ms/sample - loss: 1.7155 - val_loss: 0.1173
# Epoch 47/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.406 - 0s 1ms/sample - loss: 1.5426 - val_loss: 0.0942
# Epoch 48/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.227 - 0s 1ms/sample - loss: 2.0087 - val_loss: 0.0744
# Epoch 49/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.316 - 0s 1ms/sample - loss: 1.5989 - val_loss: 0.0483
# Epoch 50/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.738 - 0s 1ms/sample - loss: 1.6077 - val_loss: 0.0361
# Epoch 51/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.444 - 0s 1ms/sample - loss: 1.3251 - val_loss: 0.0283
# Epoch 52/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.423 - 0s 1ms/sample - loss: 1.8224 - val_loss: 0.0227
# Epoch 53/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.432 - 0s 1ms/sample - loss: 1.6134 - val_loss: 0.0246
# Epoch 54/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.469 - 0s 1ms/sample - loss: 1.4570 - val_loss: 0.0321
# Epoch 55/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.182 - 0s 2ms/sample - loss: 1.4092 - val_loss: 0.0500
# Epoch 56/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.245 - 0s 2ms/sample - loss: 1.4665 - val_loss: 0.0444
# Epoch 57/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.399 - 0s 2ms/sample - loss: 1.5203 - val_loss: 0.0315
# 0.07636988758287139
# Train on 11 samples, validate on 1 samples
# Epoch 1/5000
# 11/11 [==============================] - ETA: 2s - loss: 3.113 - 1s 49ms/sample - loss: 2.6815 - val_loss: 7.8208
# Epoch 2/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.427 - 0s 1ms/sample - loss: 2.1293 - val_loss: 8.7615
# Epoch 3/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.807 - 0s 1ms/sample - loss: 2.2025 - val_loss: 9.7122
# Epoch 4/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.569 - 0s 1ms/sample - loss: 2.2038 - val_loss: 6.6026
# Epoch 5/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.174 - 0s 2ms/sample - loss: 2.1109 - val_loss: 4.2495
# Epoch 6/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.164 - 0s 1ms/sample - loss: 1.5972 - val_loss: 2.5669
# Epoch 7/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.695 - 0s 2ms/sample - loss: 2.1590 - val_loss: 1.7299
# Epoch 8/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.625 - 0s 2ms/sample - loss: 1.8226 - val_loss: 1.4274
# Epoch 9/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.149 - 0s 2ms/sample - loss: 2.0821 - val_loss: 1.0039
# Epoch 10/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.573 - 0s 2ms/sample - loss: 2.0007 - val_loss: 0.7859
# Epoch 11/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.694 - 0s 2ms/sample - loss: 2.0084 - val_loss: 0.4761
# Epoch 12/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.554 - 0s 2ms/sample - loss: 1.9371 - val_loss: 0.2104
# Epoch 13/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.136 - 0s 2ms/sample - loss: 1.4642 - val_loss: 0.1000
# Epoch 14/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.728 - 0s 2ms/sample - loss: 2.1173 - val_loss: 0.0389
# Epoch 15/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.459 - 0s 2ms/sample - loss: 1.9496 - val_loss: 0.0262
# Epoch 16/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.234 - 0s 2ms/sample - loss: 1.7808 - val_loss: 0.0076
# Epoch 17/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.726 - 0s 1ms/sample - loss: 1.9182 - val_loss: 0.0012
# Epoch 18/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.423 - 0s 1ms/sample - loss: 1.1947 - val_loss: 5.6982e-05
# Epoch 19/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.525 - 0s 1ms/sample - loss: 1.7138 - val_loss: 4.0531e-05
# Epoch 20/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.725 - 0s 1ms/sample - loss: 2.2445 - val_loss: 1.4293e-04
# Epoch 21/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.258 - 0s 1ms/sample - loss: 1.3957 - val_loss: 5.1441e-04
# Epoch 22/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.740 - 0s 2ms/sample - loss: 2.0496 - val_loss: 0.0019
# Epoch 23/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.098 - 0s 1ms/sample - loss: 1.7788 - val_loss: 0.0044
# Epoch 24/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.314 - 0s 1ms/sample - loss: 2.0976 - val_loss: 1.2100e-04
# Epoch 25/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.737 - 0s 1ms/sample - loss: 1.9717 - val_loss: 1.0133e-04
# Epoch 26/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.119 - 0s 1ms/sample - loss: 1.6561 - val_loss: 0.0027
# Epoch 27/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.416 - 0s 1ms/sample - loss: 1.7286 - val_loss: 0.0068
# Epoch 28/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.152 - 0s 1ms/sample - loss: 1.7757 - val_loss: 0.0074
# Epoch 29/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.101 - 0s 1ms/sample - loss: 1.2644 - val_loss: 0.0062
# Epoch 30/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.187 - 0s 2ms/sample - loss: 1.7295 - val_loss: 0.0038
# Epoch 31/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.268 - 0s 1ms/sample - loss: 2.2348 - val_loss: 8.7143e-05
# Epoch 32/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.361 - 0s 1ms/sample - loss: 1.4578 - val_loss: 0.0017
# Epoch 33/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.735 - 0s 2ms/sample - loss: 2.0585 - val_loss: 0.0083
# Epoch 34/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.736 - 0s 1ms/sample - loss: 2.0847 - val_loss: 0.0071
# Epoch 35/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.133 - 0s 1ms/sample - loss: 1.3846 - val_loss: 0.0025
# Epoch 36/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.456 - 0s 2ms/sample - loss: 1.5867 - val_loss: 2.6811e-04
# Epoch 37/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.185 - 0s 2ms/sample - loss: 1.5731 - val_loss: 2.4868e-04
# Epoch 38/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.202 - 0s 1ms/sample - loss: 1.8027 - val_loss: 4.3406e-04
# Epoch 39/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.741 - 0s 2ms/sample - loss: 1.6176 - val_loss: 2.6584e-05
# Epoch 40/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.733 - 0s 1ms/sample - loss: 1.6473 - val_loss: 0.0013
# Epoch 41/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.442 - 0s 1ms/sample - loss: 1.7015 - val_loss: 0.0068
# Epoch 42/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.165 - 0s 1ms/sample - loss: 2.1400 - val_loss: 0.0115
# Epoch 43/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.090 - 0s 1ms/sample - loss: 1.9353 - val_loss: 0.0144
# Epoch 44/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.220 - 0s 1ms/sample - loss: 1.9393 - val_loss: 0.0252
# Epoch 45/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.128 - 0s 1ms/sample - loss: 1.3951 - val_loss: 0.0186
# Epoch 46/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.296 - 0s 1ms/sample - loss: 1.5970 - val_loss: 0.0146
# Epoch 47/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.426 - 0s 1ms/sample - loss: 1.5338 - val_loss: 0.0106
# Epoch 48/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.284 - 0s 1ms/sample - loss: 2.1187 - val_loss: 0.0073
# Epoch 49/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.374 - 0s 1ms/sample - loss: 1.4187 - val_loss: 0.0069
# Epoch 50/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.736 - 0s 1ms/sample - loss: 1.6485 - val_loss: 0.0037
# Epoch 51/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.502 - 0s 1ms/sample - loss: 1.4662 - val_loss: 0.0021
# Epoch 52/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.418 - 0s 1ms/sample - loss: 1.6443 - val_loss: 0.0021
# Epoch 53/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.224 - 0s 2ms/sample - loss: 1.7818 - val_loss: 0.0033
# Epoch 54/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.341 - 0s 1ms/sample - loss: 1.5951 - val_loss: 0.0087
# Epoch 55/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.272 - 0s 1ms/sample - loss: 1.4775 - val_loss: 0.0171
# Epoch 56/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.194 - 0s 1ms/sample - loss: 1.4513 - val_loss: 0.0156
# Epoch 57/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.403 - 0s 2ms/sample - loss: 1.6379 - val_loss: 0.0159
# Epoch 58/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.162 - 0s 1ms/sample - loss: 1.8560 - val_loss: 0.0262
# Epoch 59/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.358 - 0s 1ms/sample - loss: 1.8164 - val_loss: 0.0338
# Epoch 60/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.102 - 0s 1ms/sample - loss: 1.6193 - val_loss: 0.0369
# Epoch 61/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.449 - 0s 1ms/sample - loss: 1.4404 - val_loss: 0.0318
# Epoch 62/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.192 - 0s 1ms/sample - loss: 1.7131 - val_loss: 0.0298
# Epoch 63/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.268 - 0s 1ms/sample - loss: 1.8519 - val_loss: 0.0494
# Epoch 64/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.131 - 0s 1ms/sample - loss: 1.8709 - val_loss: 0.0642
# Epoch 65/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.740 - 0s 1ms/sample - loss: 1.8505 - val_loss: 0.0547
# Epoch 66/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.412 - 0s 1ms/sample - loss: 1.5738 - val_loss: 0.0386
# Epoch 67/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.126 - 0s 1ms/sample - loss: 2.0642 - val_loss: 0.0399
# Epoch 68/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.431 - 0s 1ms/sample - loss: 1.5456 - val_loss: 0.0441
# Epoch 69/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.487 - 0s 1ms/sample - loss: 1.8672 - val_loss: 0.0314
# Epoch 70/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.523 - 0s 1ms/sample - loss: 1.5617 - val_loss: 0.0244
# Epoch 71/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.146 - 0s 1ms/sample - loss: 1.4425 - val_loss: 0.0227
# Epoch 72/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.451 - 0s 1ms/sample - loss: 1.3144 - val_loss: 0.0218
# Epoch 73/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.727 - 0s 1ms/sample - loss: 2.1855 - val_loss: 0.0213
# Epoch 74/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.383 - 0s 1ms/sample - loss: 1.8124 - val_loss: 0.0201
# Epoch 75/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.726 - 0s 2ms/sample - loss: 1.6750 - val_loss: 0.0135
# Epoch 76/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.360 - 0s 1ms/sample - loss: 1.6434 - val_loss: 0.0064
# Epoch 77/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.260 - 0s 1ms/sample - loss: 1.8757 - val_loss: 0.0014
# Epoch 78/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.422 - 0s 1ms/sample - loss: 1.8809 - val_loss: 3.4882e-04
# Epoch 79/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.251 - 0s 1ms/sample - loss: 2.0618 - val_loss: 2.4557e-05
# Epoch 80/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.135 - 0s 1ms/sample - loss: 1.5330 - val_loss: 2.7776e-04
# Epoch 81/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.087 - 0s 2ms/sample - loss: 1.5159 - val_loss: 3.0745e-04
# Epoch 82/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.237 - 0s 1ms/sample - loss: 1.8769 - val_loss: 0.0144
# Epoch 83/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.351 - 0s 1ms/sample - loss: 1.8397 - val_loss: 0.0272
# Epoch 84/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.745 - 0s 1ms/sample - loss: 1.9630 - val_loss: 0.0273
# Epoch 85/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.411 - 0s 1ms/sample - loss: 2.0243 - val_loss: 0.0321
# Epoch 86/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.433 - 0s 1ms/sample - loss: 1.6415 - val_loss: 0.0243
# Epoch 87/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.398 - 0s 2ms/sample - loss: 1.7564 - val_loss: 0.0054
# Epoch 88/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.102 - 0s 2ms/sample - loss: 1.6375 - val_loss: 3.9758e-04
# Epoch 89/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.400 - 0s 2ms/sample - loss: 1.5875 - val_loss: 3.1234e-04
# Epoch 90/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.741 - 0s 1ms/sample - loss: 1.7212 - val_loss: 0.0013
# Epoch 91/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.418 - 0s 1ms/sample - loss: 1.5960 - val_loss: 6.9944e-04
# Epoch 92/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.433 - 0s 2ms/sample - loss: 1.9392 - val_loss: 2.0981e-05
# Epoch 93/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.100 - 0s 1ms/sample - loss: 1.3222 - val_loss: 4.8520e-04
# Epoch 94/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.109 - 0s 1ms/sample - loss: 1.6110 - val_loss: 0.0016
# Epoch 95/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.103 - 0s 1ms/sample - loss: 1.8416 - val_loss: 0.0034
# Epoch 96/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.495 - 0s 1ms/sample - loss: 1.8106 - val_loss: 0.0027
# Epoch 97/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.242 - 0s 1ms/sample - loss: 1.9895 - val_loss: 3.5405e-05
# Epoch 98/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.218 - 0s 1ms/sample - loss: 2.0881 - val_loss: 7.8981e-04
# Epoch 99/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.116 - 0s 1ms/sample - loss: 1.6727 - val_loss: 0.0013
# Epoch 100/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.464 - 0s 1ms/sample - loss: 1.5099 - val_loss: 0.0029
# Epoch 101/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.421 - 0s 1ms/sample - loss: 1.9680 - val_loss: 0.0035
# Epoch 102/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.237 - 0s 1ms/sample - loss: 1.6152 - val_loss: 0.0029
# Epoch 103/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.198 - 0s 1ms/sample - loss: 1.9303 - val_loss: 0.0025
# Epoch 104/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.348 - 0s 1ms/sample - loss: 1.5815 - val_loss: 2.0314e-04
# Epoch 105/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.404 - 0s 1ms/sample - loss: 1.6058 - val_loss: 9.8105e-04
# Epoch 106/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.362 - 0s 1ms/sample - loss: 1.7946 - val_loss: 0.0033
# Epoch 107/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.410 - 0s 2ms/sample - loss: 1.5419 - val_loss: 0.0041
# Epoch 108/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.417 - 0s 1ms/sample - loss: 1.6868 - val_loss: 0.0066
# Epoch 109/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.041 - 0s 1ms/sample - loss: 1.6451 - val_loss: 0.0067
# Epoch 110/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.136 - 0s 1ms/sample - loss: 1.3519 - val_loss: 0.0030
# Epoch 111/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.733 - 0s 1ms/sample - loss: 1.6909 - val_loss: 6.6892e-04
# Epoch 112/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.738 - 0s 1ms/sample - loss: 2.0502 - val_loss: 7.6414e-05
# Epoch 113/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.211 - 0s 1ms/sample - loss: 2.1750 - val_loss: 9.8940e-04
# Epoch 114/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.150 - 0s 1ms/sample - loss: 2.0431 - val_loss: 0.0023
# Epoch 115/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.160 - 0s 1ms/sample - loss: 1.2943 - val_loss: 0.0027
# Epoch 116/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.388 - 0s 1ms/sample - loss: 2.1607 - val_loss: 3.1925e-04
# Epoch 117/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.133 - 0s 1ms/sample - loss: 1.5882 - val_loss: 2.5988e-05
# Epoch 118/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.421 - 0s 1ms/sample - loss: 2.1836 - val_loss: 2.2769e-05
# Epoch 119/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.070 - 0s 1ms/sample - loss: 2.0485 - val_loss: 0.0011
# Epoch 120/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.741 - 0s 1ms/sample - loss: 2.0222 - val_loss: 0.0040
# Epoch 121/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.369 - 0s 1ms/sample - loss: 1.8109 - val_loss: 0.0031
# Epoch 122/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.738 - 0s 1ms/sample - loss: 2.3070 - val_loss: 0.0026
# Epoch 123/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.120 - 0s 1ms/sample - loss: 1.5691 - val_loss: 0.0013
# Epoch 124/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.392 - 0s 1ms/sample - loss: 1.6600 - val_loss: 6.5449e-04
# Epoch 125/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.155 - 0s 1ms/sample - loss: 1.9405 - val_loss: 9.0046e-04
# Epoch 126/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.177 - 0s 2ms/sample - loss: 1.8026 - val_loss: 0.0052
# Epoch 127/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.543 - 0s 1ms/sample - loss: 1.6198 - val_loss: 0.0131
# Epoch 128/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.509 - 0s 1ms/sample - loss: 1.5668 - val_loss: 0.0148
# Epoch 129/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.068 - 0s 2ms/sample - loss: 1.6982 - val_loss: 0.0100
# Epoch 130/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.356 - 0s 2ms/sample - loss: 1.9113 - val_loss: 0.0102
# Epoch 131/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.367 - 0s 1ms/sample - loss: 1.9966 - val_loss: 0.0055
# Epoch 132/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.253 - 0s 1ms/sample - loss: 1.8245 - val_loss: 0.0012
# Epoch 133/5000
# ...
# Epoch 140/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.406 - 0s 1ms/sample - loss: 1.5896 - val_loss: 6.9527e-04
# Epoch 141/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.203 - 0s 2ms/sample - loss: 1.8422 - val_loss: 2.7895e-05
# Epoch 142/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.416 - 0s 1ms/sample - loss: 1.9485 - val_loss: 0.0014
# Epoch 143/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.193 - 0s 2ms/sample - loss: 1.7321 - val_loss: 8.9747e-04
# Epoch 144/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.532 - 0s 1ms/sample - loss: 1.7899 - val_loss: 2.7156e-04
# Epoch 145/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.403 - 0s 1ms/sample - loss: 1.5700 - val_loss: 7.3056e-04
# Epoch 146/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.515 - 0s 1ms/sample - loss: 1.6898 - val_loss: 0.0056
# Epoch 147/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.263 - 0s 1ms/sample - loss: 1.7085 - val_loss: 0.0117
# Epoch 148/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.282 - 0s 1ms/sample - loss: 1.5263 - val_loss: 0.0209
# Epoch 149/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.450 - 0s 1ms/sample - loss: 2.0128 - val_loss: 0.0255
# Epoch 150/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.433 - 0s 1ms/sample - loss: 1.4415 - val_loss: 0.0250
# Epoch 151/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.237 - 0s 1ms/sample - loss: 1.6688 - val_loss: 0.0201
# Epoch 152/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.134 - 0s 2ms/sample - loss: 1.3224 - val_loss: 0.0151
# Epoch 153/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.485 - 0s 2ms/sample - loss: 1.7035 - val_loss: 0.0100
# Epoch 154/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.227 - 0s 1ms/sample - loss: 1.9774 - val_loss: 0.0073
# Epoch 155/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.133 - 0s 2ms/sample - loss: 1.3914 - val_loss: 0.0036
# Epoch 156/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.135 - 0s 1ms/sample - loss: 1.7297 - val_loss: 9.7688e-04
# Epoch 157/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.258 - 0s 1ms/sample - loss: 1.7212 - val_loss: 1.5557e-04
# Epoch 158/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.238 - 0s 1ms/sample - loss: 1.8660 - val_loss: 0.0011
# Epoch 159/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.245 - 0s 1ms/sample - loss: 1.5749 - val_loss: 0.0043
# Epoch 160/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.465 - 0s 1ms/sample - loss: 1.3683 - val_loss: 0.0080
# Epoch 161/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.735 - 0s 1ms/sample - loss: 1.8668 - val_loss: 0.0089
# Epoch 162/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.367 - 0s 1ms/sample - loss: 1.5522 - val_loss: 0.0018
# Epoch 163/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.735 - 0s 1ms/sample - loss: 1.6147 - val_loss: 7.7367e-05
# Epoch 164/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.198 - 0s 2ms/sample - loss: 1.6062 - val_loss: 2.8337e-04
# Epoch 165/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.107 - 0s 1ms/sample - loss: 1.7647 - val_loss: 6.0454e-04
# Epoch 166/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.273 - 0s 1ms/sample - loss: 1.8679 - val_loss: 0.0060
# Epoch 167/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.114 - 0s 2ms/sample - loss: 1.7720 - val_loss: 0.0117
# Epoch 168/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.185 - 0s 1ms/sample - loss: 1.8039 - val_loss: 0.0054
# Epoch 169/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.276 - 0s 1ms/sample - loss: 2.0167 - val_loss: 0.0025
# Epoch 170/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.120 - 0s 1ms/sample - loss: 1.8631 - val_loss: 0.0047
# Epoch 171/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.101 - 0s 1ms/sample - loss: 2.0854 - val_loss: 0.0043
# Epoch 172/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.284 - 0s 2ms/sample - loss: 1.5864 - val_loss: 0.0021
# Epoch 173/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.101 - 0s 1ms/sample - loss: 1.9779 - val_loss: 0.0013
# Epoch 174/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.117 - 0s 1ms/sample - loss: 1.9749 - val_loss: 0.0028
# Epoch 175/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.349 - 0s 1ms/sample - loss: 1.8064 - val_loss: 0.0031
# Epoch 176/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.159 - 0s 1ms/sample - loss: 1.5706 - val_loss: 0.0034
# Epoch 177/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.733 - 0s 1ms/sample - loss: 1.8798 - val_loss: 0.0076
# Epoch 178/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.223 - 0s 1ms/sample - loss: 1.8546 - val_loss: 0.0160
# Epoch 179/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.370 - 0s 2ms/sample - loss: 1.8832 - val_loss: 0.0160
# Epoch 180/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.482 - 0s 2ms/sample - loss: 1.3770 - val_loss: 0.0113
# Epoch 181/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.462 - 0s 1ms/sample - loss: 1.5665 - val_loss: 0.0071
# Epoch 182/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.497 - 0s 1ms/sample - loss: 2.0423 - val_loss: 0.0054
# Epoch 183/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.117 - 0s 2ms/sample - loss: 1.7404 - val_loss: 0.0044
# Epoch 184/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.395 - 0s 2ms/sample - loss: 1.7118 - val_loss: 0.0043
# Epoch 185/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.736 - 0s 1ms/sample - loss: 1.6896 - val_loss: 0.0016
# Epoch 186/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.513 - 0s 1ms/sample - loss: 1.6319 - val_loss: 0.0019
# Epoch 187/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.743 - 0s 1ms/sample - loss: 1.8915 - val_loss: 0.0024
# Epoch 188/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.474 - 0s 2ms/sample - loss: 1.8378 - val_loss: 0.0040
# Epoch 189/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.099 - 0s 1ms/sample - loss: 1.5788 - val_loss: 0.0053
# Epoch 190/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.117 - 0s 1ms/sample - loss: 1.7846 - val_loss: 0.0072
# Epoch 191/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.110 - 0s 2ms/sample - loss: 1.6766 - val_loss: 0.0075
# 0.001554357538984234
# Train on 11 samples, validate on 1 samples
# Epoch 1/5000
# 11/11 [==============================] - ETA: 1s - loss: 2.225 - 0s 39ms/sample - loss: 2.3251 - val_loss: 3.9078
# Epoch 2/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.939 - 0s 2ms/sample - loss: 2.1399 - val_loss: 3.5741
# Epoch 3/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.544 - 0s 2ms/sample - loss: 2.0424 - val_loss: 1.7414
# Epoch 4/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.561 - 0s 1ms/sample - loss: 2.1331 - val_loss: 1.1875
# Epoch 5/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.680 - 0s 2ms/sample - loss: 1.9936 - val_loss: 0.8482
# Epoch 6/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.597 - 0s 2ms/sample - loss: 1.5249 - val_loss: 0.6682
# Epoch 7/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.141 - 0s 1ms/sample - loss: 2.0783 - val_loss: 0.6629
# Epoch 8/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.501 - 0s 2ms/sample - loss: 1.6888 - val_loss: 0.5258
# Epoch 9/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.133 - 0s 1ms/sample - loss: 1.9046 - val_loss: 0.5479
# Epoch 10/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.437 - 0s 2ms/sample - loss: 1.5901 - val_loss: 0.5604
# Epoch 11/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.957 - 0s 1ms/sample - loss: 1.7843 - val_loss: 0.5717
# Epoch 12/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.460 - 0s 1ms/sample - loss: 1.8928 - val_loss: 0.5262
# Epoch 13/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.557 - 0s 1ms/sample - loss: 1.4131 - val_loss: 0.3774
# Epoch 14/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.082 - 0s 2ms/sample - loss: 1.8149 - val_loss: 0.3627
# Epoch 15/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.500 - 0s 1ms/sample - loss: 1.7930 - val_loss: 0.4420
# Epoch 16/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.357 - 0s 1ms/sample - loss: 1.7528 - val_loss: 0.4169
# Epoch 17/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.143 - 0s 1ms/sample - loss: 1.9584 - val_loss: 0.3338
# Epoch 18/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.302 - 0s 2ms/sample - loss: 1.1796 - val_loss: 0.2625
# Epoch 19/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.566 - 0s 2ms/sample - loss: 1.7560 - val_loss: 0.2197
# Epoch 20/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.738 - 0s 1ms/sample - loss: 2.1557 - val_loss: 0.2085
# Epoch 21/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.420 - 0s 2ms/sample - loss: 1.4926 - val_loss: 0.1917
# Epoch 22/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.743 - 0s 2ms/sample - loss: 2.1671 - val_loss: 0.1852
# Epoch 23/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.487 - 0s 1ms/sample - loss: 1.7724 - val_loss: 0.1863
# Epoch 24/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.467 - 0s 1ms/sample - loss: 1.8343 - val_loss: 0.2059
# Epoch 25/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.738 - 0s 1ms/sample - loss: 2.1220 - val_loss: 0.2251
# Epoch 26/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.098 - 0s 1ms/sample - loss: 1.6226 - val_loss: 0.2549
# Epoch 27/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.444 - 0s 1ms/sample - loss: 1.6583 - val_loss: 0.3515
# Epoch 28/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.029 - 0s 1ms/sample - loss: 1.6297 - val_loss: 0.4799
# Epoch 29/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.507 - 0s 1ms/sample - loss: 1.3604 - val_loss: 0.5202
# Epoch 30/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.729 - 0s 1ms/sample - loss: 1.9226 - val_loss: 0.5145
# Epoch 31/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.444 - 0s 1ms/sample - loss: 1.9841 - val_loss: 0.4633
# Epoch 32/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.480 - 0s 2ms/sample - loss: 1.3166 - val_loss: 0.3964
# Epoch 33/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.193 - 0s 1ms/sample - loss: 2.0762 - val_loss: 0.4392
# Epoch 34/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.170 - 0s 1ms/sample - loss: 2.1233 - val_loss: 0.4946
# Epoch 35/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.369 - 0s 2ms/sample - loss: 1.4001 - val_loss: 0.4773
# Epoch 36/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.477 - 0s 1ms/sample - loss: 1.6925 - val_loss: 0.4166
# Epoch 37/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.329 - 0s 1ms/sample - loss: 1.4864 - val_loss: 0.3577
# Epoch 38/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.735 - 0s 1ms/sample - loss: 1.7979 - val_loss: 0.3374
# Epoch 39/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.735 - 0s 1ms/sample - loss: 1.7850 - val_loss: 0.3368
# Epoch 40/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.226 - 0s 1ms/sample - loss: 1.6859 - val_loss: 0.3712
# Epoch 41/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.097 - 0s 1ms/sample - loss: 1.7884 - val_loss: 0.3592
# Epoch 42/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.272 - 0s 1ms/sample - loss: 2.0684 - val_loss: 0.3145
# Epoch 43/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.741 - 0s 1ms/sample - loss: 2.1602 - val_loss: 0.3360
# Epoch 44/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.258 - 0s 1ms/sample - loss: 1.8440 - val_loss: 0.3830
# Epoch 45/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.102 - 0s 1ms/sample - loss: 1.3785 - val_loss: 0.4331
# Epoch 46/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.167 - 0s 1ms/sample - loss: 1.7640 - val_loss: 0.4920
# Epoch 47/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.511 - 0s 1ms/sample - loss: 1.4511 - val_loss: 0.5059
# Epoch 48/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.431 - 0s 1ms/sample - loss: 1.8824 - val_loss: 0.5341
# Epoch 49/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.391 - 0s 1ms/sample - loss: 1.4309 - val_loss: 0.5640
# Epoch 50/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.121 - 0s 1ms/sample - loss: 1.5200 - val_loss: 0.5461
# Epoch 51/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.387 - 0s 1ms/sample - loss: 1.2379 - val_loss: 0.5021
# Epoch 52/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.401 - 0s 1ms/sample - loss: 1.9682 - val_loss: 0.4549
# Epoch 53/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.406 - 0s 1ms/sample - loss: 1.8002 - val_loss: 0.4017
# Epoch 54/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.393 - 0s 1ms/sample - loss: 1.2929 - val_loss: 0.3607
# Epoch 55/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.740 - 0s 2ms/sample - loss: 1.5087 - val_loss: 0.3081
# Epoch 56/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.189 - 0s 1ms/sample - loss: 1.5122 - val_loss: 0.3150
# Epoch 57/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.262 - 0s 2ms/sample - loss: 1.6513 - val_loss: 0.3490
# Epoch 58/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.190 - 0s 1ms/sample - loss: 1.6910 - val_loss: 0.4044
# Epoch 59/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.413 - 0s 1ms/sample - loss: 2.0040 - val_loss: 0.4343
# Epoch 60/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.420 - 0s 1ms/sample - loss: 1.5837 - val_loss: 0.4486
# Epoch 61/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.297 - 0s 2ms/sample - loss: 1.7238 - val_loss: 0.4516
# Epoch 62/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.365 - 0s 1ms/sample - loss: 1.7042 - val_loss: 0.5099
# Epoch 63/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.743 - 0s 1ms/sample - loss: 1.8254 - val_loss: 0.5309
# Epoch 64/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.361 - 0s 1ms/sample - loss: 1.8264 - val_loss: 0.5182
# Epoch 65/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.191 - 0s 1ms/sample - loss: 1.8143 - val_loss: 0.5053
# Epoch 66/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.231 - 0s 1ms/sample - loss: 1.6326 - val_loss: 0.4895
# Epoch 67/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.187 - 0s 1ms/sample - loss: 1.8583 - val_loss: 0.4819
# Epoch 68/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.414 - 0s 1ms/sample - loss: 1.5409 - val_loss: 0.4652
# Epoch 69/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.129 - 0s 1ms/sample - loss: 1.6582 - val_loss: 0.4210
# Epoch 70/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.417 - 0s 2ms/sample - loss: 1.7236 - val_loss: 0.3940
# Epoch 71/5000
# 11/11 [==============================] - ETA: 0s - loss: 2.736 - 0s 1ms/sample - loss: 1.6018 - val_loss: 0.3572
# Epoch 72/5000
# 11/11 [==============================] - ETA: 0s - loss: 1.471 - 0s 2ms/sample - loss: 1.3965 - val_loss: 0.3026
# 0.43031183036803106

# %%
# Collect and print results, plot predictions with respect to ground truth
angles = []
for i in range(all_preds.shape[0]):
    angles.append(math.atan2(all_preds[i, 0], all_preds[i, 1]) / math.pi * 12)

for j in range(len(angles)):
    if angles[j] < 0:
        angles[j] = angles[j] + 24

plt.figure(dpi=500)
ax = sn.scatterplot(Y_data[:, 0], Y_data[:, 1])
ax = sn.scatterplot(all_preds[:, 0], all_preds[:, 1])
plt.show()
angles_arr = np.vstack(angles)
hour_pred = angles_arr

plt.figure(dpi=500)
ax = sn.lineplot(np.arange(Y_copy.shape[0]), Y_copy)
ax = sn.lineplot(np.arange(Y_copy.shape[0]), angles_arr.ravel())
plt.show()


angles = []
for i in range(all_preds.shape[0]):
    angles.append(math.atan2(all_preds[i, 0], all_preds[i, 1]) / math.pi * 12)

for j in range(len(angles)):
    if angles[j] < 0:
        angles[j] = angles[j] + 24


valid_angles = []
valid_preds = np.mean(valid_preds, axis=0)
for i in range(valid_preds.shape[0]):
    valid_angles.append(math.atan2(valid_preds[i, 0], valid_preds[i, 1]) / math.pi * 12)

for j in range(len(valid_angles)):
    if valid_angles[j] < 0:
        valid_angles[j] = valid_angles[j] + 24
valid_preds = normalize(valid_preds)
plt.figure(dpi=500)
ax = sn.scatterplot(Y_valid_data[:, 0], Y_valid_data[:, 1])
ax = sn.scatterplot(valid_preds[:, 0], valid_preds[:, 1])
plt.show()
angles_arr_valid = np.vstack(valid_angles)
hour_pred_valid = angles_arr_valid


plt.figure(dpi=500)
ax = sn.lineplot(np.arange(Y_valid_copy.shape[0]), Y_valid_copy)
ax = sn.lineplot(np.arange(Y_valid_copy.shape[0]), angles_arr_valid.ravel())
plt.show()

print("Average training error = {} minutes".format(60 * 12 * cyclical_loss(Y_data.astype('float64'), all_preds.astype('float64')) / (Y_data.shape[0] * np.pi)))

print("Average validation error = {} minutes".format(60 * 12 * cyclical_loss(Y_valid_data.astype('float64'), valid_preds.astype('float64')) / (Y_valid_data.shape[0] * np.pi)))

Y_copy1 = np.array([2, 5, 8, 11, 14, 17, 20, 23, 2, 5, 8, 11, 14, 17, 20, 23])

test_angles = []
test_preds_copy = test_preds
test_preds = np.mean(test_preds, axis=0)
for j in range(len(test_preds_copy)):
    for i in range(test_preds.shape[0]):
        test_preds_copy[j][i, 0] = math.atan2(test_preds_copy[j][i, 0], test_preds_copy[j][i, 1]) / math.pi * 12
        if test_preds_copy[j][i, 0] < 0:
            test_preds_copy[j][i, 0] += 24
    test_preds_copy[j] = np.delete(test_preds_copy[j], 1, 1)

for i in range(test_preds.shape[0]):
    test_angles.append(math.atan2(test_preds[i, 0], test_preds[i, 1]) / math.pi * 12)
for j in range(len(test_angles)):
    if test_angles[j] < 0:
        test_angles[j] = test_angles[j] + 24
test_preds = normalize(test_preds)
angles_arr_test = np.vstack(test_angles)
hour_pred_test = angles_arr_test
Y_test = np.array([12, 0, 12, 0])

Y_test_cos = -np.cos((2 * np.pi * Y_test.astype('float64') / 24) + (np.pi / 2))
Y_test_sin = np.sin((2 * np.pi * Y_test.astype('float64') / 24) + (np.pi / 2))
Y_test_ang = np.concatenate((Y_test_cos.reshape(-1, 1), Y_test_sin.reshape(-1, 1)), axis=1)
print("Average test error = {} minutes".format(60 * 12 * cyclical_loss(Y_test_ang.astype('float64'), test_preds.astype('float64')) / (Y_test_ang.shape[0] * np.pi)))
val_errors1.append(60 * 12 * cyclical_loss(Y_valid_data.astype('float64'), all_valid_preds.astype('float64')) / (Y_valid_data.shape[0] * np.pi))
test_errors1.append(60 * 12 * cyclical_loss(Y_test_ang.astype('float64'), test_preds.astype('float64')) / (Y_test_ang.shape[0] * np.pi))

print(L['moduleColor'].value_counts())
# Out:
# Average training error = 11.496838081806102 minutes
# Average validation error = 90.43928402856271 minutes
# Average test error = 67.7013746901371 minutes
# pink         8
# None         8
# blue         8
# black        8
# brown        8
# red          8
# green        8
# yellow       8
# turquoise    8
# Name: moduleColor, dtype: int64
