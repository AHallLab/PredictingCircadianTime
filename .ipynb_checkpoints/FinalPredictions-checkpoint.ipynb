# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import seaborn as sn
import math
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler, normalize
from functools import reduce
import random
from numpy.linalg import norm
import os

# %%
val_errors1 = []
test_errors1 = []

SEED = 1000
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

df = pd.read_csv('Data\\X_train_raw.csv').T
df_valid = pd.read_csv('Data\\X_valid_raw.csv').T
df_test = pd.concat((pd.read_csv('Data\\X_test_raw_A.txt').T, pd.read_csv('Data\\X_test_raw_B.txt').T)).iloc[[0, 1, 2, 4, 5], :]
rach_clusters = pd.read_csv('Data\\X_train_clusters.csv')
Y_data = df.iloc[1:, -1].astype('float64')
Y_copy = Y_data
Y_valid_data = df_valid.iloc[1:, -1].astype('float64')
Y_valid_copy = Y_valid_data

common_IDs = reduce(np.intersect1d, (df.iloc[0, :-1].values, df_valid.iloc[0, :-1].values, df_test.iloc[0, :].values))

idx = np.where(df.iloc[0, :].isin(common_IDs))[0]
df = df.iloc[:, idx]
idx_valid = np.where(df_valid.iloc[0, :].isin(common_IDs))[0]
df_valid = df_valid.iloc[:, idx_valid]
idx_test = np.where(df_test.iloc[0, :].isin(common_IDs))[0]
df_test = df_test.iloc[:, idx_test]

X_data = df.iloc[1:, :].astype('float64')
X_ID = df.iloc[0, :]
X_valid_data = df_valid.iloc[1:, :].astype('float64')
X_valid_ID = df_valid.iloc[0, :]
X_test_data = df_test.iloc[1:, :].astype('float64')
X_test_ID = df_test.iloc[0, :]

X_ID1 = np.argsort(X_ID)
X_ID = X_ID.iloc[X_ID1]
X_data = X_data.iloc[:, X_ID1]
X_data.columns = X_ID
X_ID1 = np.argsort(X_valid_ID)
X_valid_ID = X_valid_ID.iloc[X_ID1]
X_valid_data = X_valid_data.iloc[:, X_ID1]
X_valid_data.columns = X_valid_ID
X_ID1 = np.argsort(X_test_ID)
X_test_ID = X_test_ID.iloc[X_ID1]
X_test_data = X_test_data.iloc[:, X_ID1]
X_test_data.columns = X_test_ID

genes = ['AT1G13650.1',
'AT3G55450.1',
'AT1G02930.2',
'AT1G79500.3',
'AT5G24850.1',
'AT5G06870.1',
'AT5G41460.1',
'AT5G01820.1',
'AT4G08870.1',
'AT1G75100.1',
'AT2G29650.2',
'AT5G06690.1',
'AT3G17609.2',
'AT4G15690.1',
'AT1G06040.1'
]

X_data = X_data.loc[:, genes]
X_valid_data = X_valid_data.loc[:, genes]
X_test_data = X_test_data.loc[:, genes]

# %%
n_folds = Y_data.shape[0]
folds = KFold(n_splits=n_folds, random_state=SEED, shuffle=True)

y_cos = -np.cos((2 * np.pi * Y_data.astype('float64') / 24)+(np.pi/2))
y_sin = np.sin((2 * np.pi * Y_data.astype('float64') / 24)+(np.pi/2))

Y_valid_cos = -np.cos((2 * np.pi * Y_valid_data.astype('float64') / 24)+(np.pi/2))
Y_valid_sin = np.sin((2 * np.pi * Y_valid_data.astype('float64') / 24)+(np.pi/2))

scaler = MinMaxScaler()
scaler.fit(X_data)
X_data = scaler.transform(X_data)
X_valid_data = scaler.transform(X_valid_data)
X_test_data = scaler.transform(X_test_data)

def cyclical_loss(y_true, y_pred):
    error = 0
    for i in range(y_pred.shape[0]):
        error += np.arccos((y_true[i, :] @ y_pred[i, :]) / (norm(y_true[i, :]) * norm(y_pred[i, :])))
    return error

def custom_loss(y_true, y_pred):
    return tf.reduce_mean((tf.math.acos(tf.matmul(y_true, tf.transpose(y_pred)) / ((tf.norm(y_true) * tf.norm(y_pred)) + tf.keras.backend.epsilon()))**2))

adam = Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, amsgrad=False)


def larger_model():
    # create model
    model = Sequential()
    model.add(Dense(32, kernel_initializer='normal', activation='relu'))
    model.add(Dense(128, kernel_initializer='normal', activation='relu'))
    model.add(Dense(512, kernel_initializer='normal', activation='relu'))
    model.add(Dense(2, kernel_initializer='normal'))
    # Compile model
    model.compile(loss=custom_loss, optimizer=adam)
    return model

Y_data = np.concatenate((y_cos.values.reshape(-1, 1), y_sin.values.reshape(-1, 1)), axis=1)
Y_valid_data = np.concatenate((Y_valid_cos.values.reshape(-1, 1), Y_valid_sin.values.reshape(-1, 1)), axis=1)

error = 0  # Initialise error
all_preds = np.zeros((Y_data.shape[0], 2))  # Create empty array
all_valid_preds = np.zeros((Y_valid_data.shape[0], 2))  # Create empty array
early_stop = EarlyStopping(patience=50, restore_best_weights=True, monitor='val_loss', mode='min')


def reset_seeds(reset_graph_with_backend=None, seed=0):
    if reset_graph_with_backend is not None:
        K = reset_graph_with_backend
        K.clear_session()
        tf.compat.v1.reset_default_graph()

    np.random.seed(seed)
    random.seed(seed)
    tf.compat.v1.set_random_seed(seed)

valid_preds = []
test_preds = []

# %%
for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_data, Y_data)):
    X_train, Y_train = X_data[train_idx], Y_data[train_idx]  # Define training data for this iteration
    X_valid, Y_valid = X_data[valid_idx], Y_data[valid_idx]
    model = larger_model()
    model.fit(X_train.astype('float64'), Y_train.astype('float64'), validation_data=(X_valid.astype('float64'), Y_valid.astype('float64')),
              batch_size=1, epochs=5000, callbacks=[early_stop])  # Fit the model on the training data
    preds = normalize(model.predict(X_valid))  # Predict on the validation data
    all_preds[valid_idx] = normalize(model.predict(X_valid))
    all_valid_preds += (normalize(model.predict(X_valid_data)) / n_folds)
    valid_preds.append(normalize(model.predict(X_valid_data)))
    test_preds.append(normalize(model.predict(X_test_data)))
    error += cyclical_loss(Y_valid.astype('float64'), preds.astype('float64'))  # Evaluate the predictions
    print(cyclical_loss(Y_valid.astype('float64'), preds.astype('float64')) / Y_valid.shape[0])
# Out:
# Epoch 1/5000
# 11/11 [==============================] - 0s 10ms/step - loss: 3.2334 - val_loss: 0.4435
# Epoch 2/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.8639 - val_loss: 0.3922
# Epoch 3/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.6958 - val_loss: 0.3352
# Epoch 4/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.4992 - val_loss: 0.2779
# Epoch 5/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2664 - val_loss: 0.2462
# Epoch 6/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0802 - val_loss: 0.2305
# Epoch 7/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7813 - val_loss: 0.2182
# Epoch 8/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.4534 - val_loss: 0.1682
# Epoch 9/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8603 - val_loss: 0.1283
# Epoch 10/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4345 - val_loss: 0.1201
# Epoch 11/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2217 - val_loss: 0.1369
# Epoch 12/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1469 - val_loss: 0.1734
# Epoch 13/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1267 - val_loss: 0.2157
# Epoch 14/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1132 - val_loss: 0.2281
# Epoch 15/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0989 - val_loss: 0.2227
# Epoch 16/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0879 - val_loss: 0.2272
# Epoch 17/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0774 - val_loss: 0.2200
# Epoch 18/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0684 - val_loss: 0.2187
# Epoch 19/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0604 - val_loss: 0.2159
# Epoch 20/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0534 - val_loss: 0.2206
# Epoch 21/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0466 - val_loss: 0.2305
# Epoch 22/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0411 - val_loss: 0.2251
# Epoch 23/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0372 - val_loss: 0.2234
# Epoch 24/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0310 - val_loss: 0.2154
# Epoch 25/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0278 - val_loss: 0.2135
# Epoch 26/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0243 - val_loss: 0.2116
# Epoch 27/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0214 - val_loss: 0.2242
# Epoch 28/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0187 - val_loss: 0.2246
# Epoch 29/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0167 - val_loss: 0.2153
# Epoch 30/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0144 - val_loss: 0.2230
# Epoch 31/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.2160
# Epoch 32/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.2204
# Epoch 33/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0096 - val_loss: 0.2156
# Epoch 34/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.2182
# Epoch 35/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.2168
# Epoch 36/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.2217
# Epoch 37/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.2145
# Epoch 38/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.2182
# Epoch 39/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.2126
# Epoch 40/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.2056
# Epoch 41/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.2085
# Epoch 42/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0029 - val_loss: 0.2071
# Epoch 43/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.2117
# Epoch 44/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.2076
# Epoch 45/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.2071
# Epoch 46/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.2041
# Epoch 47/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.2068
# Epoch 48/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.2092
# Epoch 49/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.2052
# Epoch 50/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.2071
# Epoch 51/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 0.2041
# Epoch 52/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 8.9495e-04 - val_loss: 0.2053
# Epoch 53/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 7.9196e-04 - val_loss: 0.2065
# Epoch 54/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 7.3396e-04 - val_loss: 0.2050
# Epoch 55/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 6.5758e-04 - val_loss: 0.2048
# Epoch 56/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 6.0042e-04 - val_loss: 0.2057
# Epoch 57/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.9037e-04 - val_loss: 0.2083
# Epoch 58/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 5.1226e-04 - val_loss: 0.2077
# Epoch 59/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 4.7623e-04 - val_loss: 0.2075
# Epoch 60/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 4.1656e-04 - val_loss: 0.2073
# 0.3464727299086937
# Epoch 1/5000
# 11/11 [==============================] - 0s 8ms/step - loss: 3.2874 - val_loss: 0.0256
# Epoch 2/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.6123 - val_loss: 0.0160
# Epoch 3/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6270 - val_loss: 0.0312
# Epoch 4/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.4127 - val_loss: 0.3446
# Epoch 5/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1872 - val_loss: 0.4531
# Epoch 6/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1255 - val_loss: 0.2664
# Epoch 7/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0834 - val_loss: 0.0627
# Epoch 8/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0619 - val_loss: 0.0100
# Epoch 9/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0493 - val_loss: 0.0025
# Epoch 10/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0409 - val_loss: 0.0033
# Epoch 11/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0319 - val_loss: 0.0028
# Epoch 12/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0274 - val_loss: 0.0024
# Epoch 13/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0235 - val_loss: 0.0030
# Epoch 14/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0203 - val_loss: 0.0023
# Epoch 15/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0174 - val_loss: 0.0018
# Epoch 16/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0022
# Epoch 17/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0020
# Epoch 18/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0037
# Epoch 19/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0104 - val_loss: 0.0043
# Epoch 20/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0097 - val_loss: 0.0036
# Epoch 21/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0081 - val_loss: 0.0045
# Epoch 22/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0047
# Epoch 23/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0067 - val_loss: 0.0043
# Epoch 24/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0048
# Epoch 25/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0041
# Epoch 26/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0041
# Epoch 27/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 28/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0054
# Epoch 29/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0052
# Epoch 30/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0055
# Epoch 31/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0056
# Epoch 32/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0059
# Epoch 33/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0060
# Epoch 34/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 35/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0058
# Epoch 36/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 37/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0064
# Epoch 38/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0064
# Epoch 39/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0062
# Epoch 40/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0065
# Epoch 41/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0061
# Epoch 42/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0063
# Epoch 43/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0064
# Epoch 44/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0064
# Epoch 45/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0063
# Epoch 46/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0062
# Epoch 47/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0067
# Epoch 48/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0071
# Epoch 49/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0071
# Epoch 50/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0068
# Epoch 51/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 52/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0067
# Epoch 53/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0071
# Epoch 54/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0071
# Epoch 55/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0069
# Epoch 56/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0068
# Epoch 57/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0072
# Epoch 58/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0070
# Epoch 59/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0064
# Epoch 60/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0067
# Epoch 61/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0068
# Epoch 62/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0070
# Epoch 63/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0071
# Epoch 64/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 9.9494e-04 - val_loss: 0.0071
# Epoch 65/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 9.8081e-04 - val_loss: 0.0073
# 0.042151358765456705
# Epoch 1/5000
# 11/11 [==============================] - 0s 8ms/step - loss: 2.6050 - val_loss: 0.0229
# Epoch 2/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7056 - val_loss: 0.0803
# Epoch 3/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.1571 - val_loss: 0.0159
# Epoch 4/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6280 - val_loss: 0.1004
# Epoch 5/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4703 - val_loss: 0.1080
# Epoch 6/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.3630 - val_loss: 0.1420
# Epoch 7/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2333 - val_loss: 0.1067
# Epoch 8/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1686 - val_loss: 0.0853
# Epoch 9/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1347 - val_loss: 0.0748
# Epoch 10/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1070 - val_loss: 0.0825
# Epoch 11/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0709 - val_loss: 0.0737
# Epoch 12/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0533 - val_loss: 0.0769
# Epoch 13/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0412 - val_loss: 0.0672
# Epoch 14/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0315 - val_loss: 0.0725
# Epoch 15/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0239 - val_loss: 0.0593
# Epoch 16/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.0527
# Epoch 17/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0156 - val_loss: 0.0510
# Epoch 18/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0122 - val_loss: 0.0461
# Epoch 19/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0103 - val_loss: 0.0398
# Epoch 20/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0373
# Epoch 21/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0344
# Epoch 22/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0282
# Epoch 23/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0243
# Epoch 24/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0228
# Epoch 25/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0207
# Epoch 26/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0183
# Epoch 27/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0184
# Epoch 28/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0168
# Epoch 29/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0162
# Epoch 30/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0163
# Epoch 31/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0152
# Epoch 32/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 9.6707e-04 - val_loss: 0.0141
# Epoch 33/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 8.7793e-04 - val_loss: 0.0139
# Epoch 34/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 7.7611e-04 - val_loss: 0.0131
# Epoch 35/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 6.8335e-04 - val_loss: 0.0131
# Epoch 36/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 6.2620e-04 - val_loss: 0.0128
# Epoch 37/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.6816e-04 - val_loss: 0.0127
# Epoch 38/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.1302e-04 - val_loss: 0.0125
# Epoch 39/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 4.6528e-04 - val_loss: 0.0120
# Epoch 40/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 4.6171e-04 - val_loss: 0.0126
# Epoch 41/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3
5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 5.3086e-04
# Epoch 30/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 1.9074e-05
# Epoch 31/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 2.9206e-05
# Epoch 32/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 2.1708e-04
# Epoch 33/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 7.4296e-04
# Epoch 34/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 5.8034e-04
# Epoch 35/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 9.8570e-04
# Epoch 36/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 37/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 38/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 39/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0039
# Epoch 40/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0056
# Epoch 41/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0060
# Epoch 42/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0074
# Epoch 43/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0082
# Epoch 44/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0088
# Epoch 45/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0091
# Epoch 46/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0104
# Epoch 47/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0121
# Epoch 48/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0135
# Epoch 49/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0138
# Epoch 50/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0141
# Epoch 51/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0146
# Epoch 52/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0155
# Epoch 53/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0174
# Epoch 54/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0176
# Epoch 55/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0181
# Epoch 56/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0189
# Epoch 57/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0206
# Epoch 58/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0213
# Epoch 59/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0206
# Epoch 60/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 9.6131e-04 - val_loss: 0.0218
# Epoch 61/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 8.9831e-04 - val_loss: 0.0221
# Epoch 62/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 8.9095e-04 - val_loss: 0.0223
# Epoch 63/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 8.4823e-04 - val_loss: 0.0239
# Epoch 64/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 8.2208e-04 - val_loss: 0.0242
# Epoch 65/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 7.9472e-04 - val_loss: 0.0252
# Epoch 66/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 8.0265e-04 - val_loss: 0.0251
# Epoch 67/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 7.4550e-04 - val_loss: 0.0257
# Epoch 68/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 6.9116e-04 - val_loss: 0.0260
# Epoch 69/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 6.8493e-04 - val_loss: 0.0272
# Epoch 70/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 6.7817e-04 - val_loss: 0.0267
# Epoch 71/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 6.4483e-04 - val_loss: 0.0268
# Epoch 72/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 5.9993e-04 - val_loss: 0.0281
# Epoch 73/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 6.1189e-04 - val_loss: 0.0290
# Epoch 74/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.7616e-04 - val_loss: 0.0283
# Epoch 75/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.4858e-04 - val_loss: 0.0287
# Epoch 76/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.4024e-04 - val_loss: 0.0291
# Epoch 77/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.3547e-04 - val_loss: 0.0299
# Epoch 78/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.3147e-04 - val_loss: 0.0300
# Epoch 79/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.0285e-04 - val_loss: 0.0298
# Epoch 80/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 4.9742e-04 - val_loss: 0.0309
# 0.0018044397974199772
# Epoch 1/5000
# 11/11 [==============================] - 0s 8ms/step - loss: 2.5147 - val_loss: 0.1033
# Epoch 2/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.2705 - val_loss: 0.4879
# Epoch 3/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.7052 - val_loss: 0.8140
# Epoch 4/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1941 - val_loss: 0.4805
# Epoch 5/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0987 - val_loss: 0.3378
# Epoch 6/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0731 - val_loss: 0.2573
# Epoch 7/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0510 - val_loss: 0.2171
# Epoch 8/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0391 - val_loss: 0.1912
# Epoch 9/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.1716
# Epoch 10/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0255 - val_loss: 0.1485
# Epoch 11/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0224 - val_loss: 0.1370
# Epoch 12/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0193 - val_loss: 0.1175
# Epoch 13/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0165 - val_loss: 0.1088
# Epoch 14/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.1092
# Epoch 15/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.1044
# Epoch 16/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.1016
# Epoch 17/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0924
# Epoch 18/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0919
# Epoch 19/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0098 - val_loss: 0.0954
# Epoch 20/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0881
# Epoch 21/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0870
# Epoch 22/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0079 - val_loss: 0.0878
# Epoch 23/5000
# ...
# Epoch 4/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0998 - val_loss: 0.0014
# Epoch 5/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 1.4299 - val_loss: 0.1863
# Epoch 6/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 1.0719 - val_loss: 0.8647
# Epoch 7/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.6165 - val_loss: 0.4714
# Epoch 8/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.4419 - val_loss: 0.5419
# Epoch 9/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2702 - val_loss: 0.4929
# Epoch 10/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1848 - val_loss: 0.5212
# Epoch 11/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1359 - val_loss: 0.3811
# Epoch 12/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0834 - val_loss: 0.3995
# Epoch 13/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0578 - val_loss: 0.3731
# Epoch 14/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.4491
# Epoch 15/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0353 - val_loss: 0.4525
# Epoch 16/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0251 - val_loss: 0.4099
# Epoch 17/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0203 - val_loss: 0.4055
# Epoch 18/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0170 - val_loss: 0.4296
# Epoch 19/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0144 - val_loss: 0.4182
# Epoch 20/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.3915
# Epoch 21/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0097 - val_loss: 0.3992
# Epoch 22/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0083 - val_loss: 0.3994
# Epoch 23/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0070 - val_loss: 0.3846
# Epoch 24/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.3702
# Epoch 25/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.3712
# Epoch 26/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.3725
# Epoch 27/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.3614
# Epoch 28/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.3518
# Epoch 29/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.3574
# Epoch 30/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.3614
# Epoch 31/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.3548
# Epoch 32/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.3486
# Epoch 33/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.3489
# Epoch 34/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.3499
# Epoch 35/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.3439
# Epoch 36/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.3406
# Epoch 37/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 9.4318e-04 - val_loss: 0.3362
# Epoch 38/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 8.0741e-04 - val_loss: 0.3382
# Epoch 39/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 7.3129e-04 - val_loss: 0.3377
# Epoch 40/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 6.6200e-04 - val_loss: 0.3329
# Epoch 41/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 5.8489e-04 - val_loss: 0.3344
# Epoch 42/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 5.0159e-04 - val_loss: 0.3317
# Epoch 43/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 4.4400e-04 - val_loss: 0.3305
# Epoch 44/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 4.1846e-04 - val_loss: 0.3298
# Epoch 45/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.6242e-04 - val_loss: 0.3319
# Epoch 46/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.2227e-04 - val_loss: 0.3270
# Epoch 47/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.9154e-04 - val_loss: 0.3240
# Epoch 48/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.7294e-04 - val_loss: 0.3256
# Epoch 49/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.3830e-04 - val_loss: 0.3245
# Epoch 50/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.1803e-04 - val_loss: 0.3239
# Epoch 51/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.0718e-04 - val_loss: 0.3230
# Epoch 52/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 1.8760e-04 - val_loss: 0.3219
# Epoch 53/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 1.7298e-04 - val_loss: 0.3214
# Epoch 54/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6039e-04 - val_loss: 0.3215
# 0.03724985999460429
# Epoch 1/5000
# 11/11 [==============================] - 0s 8ms/step - loss: 2.4535 - val_loss: 3.5177
# Epoch 2/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7053 - val_loss: 2.3103
# Epoch 3/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.9190 - val_loss: 0.5801
# Epoch 4/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5351 - val_loss: 0.0746
# Epoch 5/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.1698 - val_loss: 0.2061
# Epoch 6/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0989 - val_loss: 0.1847
# Epoch 7/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0609 - val_loss: 0.1487
# Epoch 8/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0440 - val_loss: 0.1174
# Epoch 9/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0311 - val_loss: 0.0960
# Epoch 10/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0234 - val_loss: 0.0845
# Epoch 11/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0196 - val_loss: 0.0702
# Epoch 12/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0164 - val_loss: 0.0591
# Epoch 13/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0516
# Epoch 14/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0471
# Epoch 15/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0421
# Epoch 16/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0090 - val_loss: 0.0363
# Epoch 17/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0304
# Epoch 18/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0265
# Epoch 19/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0249
# Epoch 20/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0205
# Epoch 21/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0047 - val_loss: 0.0184
# Epoch 22/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0162
# Epoch 23/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0138
# Epoch 24/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0129
# Epoch 25/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0105
# Epoch 26/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0090
# Epoch 27/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0080
# Epoch 28/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0067
# Epoch 29/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0056
# Epoch 30/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0047
# Epoch 31/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0045
# Epoch 32/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 33/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 34/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 35/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 36/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 9.9055e-04 - val_loss: 0.0018
# Epoch 37/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 9.0851e-04 - val_loss: 0.0015
# Epoch 38/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 8.7840e-04 - val_loss: 0.0010
# Epoch 39/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 7.7098e-04 - val_loss: 8.5110e-04
# Epoch 40/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 6.9708e-04 - val_loss: 7.4952e-04
# Epoch 41/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 6.5708e-04 - val_loss: 5.3706e-04
# Epoch 42/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.8321e-04 - val_loss: 4.5873e-04
# Epoch 43/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.3873e-04 - val_loss: 3.5382e-04
# Epoch 44/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 5.0601e-04 - val_loss: 2.3318e-04
# Epoch 45/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 4.5164e-04 - val_loss: 1.5664e-04
# Epoch 46/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 4.1393e-04 - val_loss: 1.0598e-04
# Epoch 47/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.7558e-04 - val_loss: 7.7010e-05
# Epoch 48/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.5830e-04 - val_loss: 3.9935e-05
# Epoch 49/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.2342e-04 - val_loss: 3.2544e-05
# Epoch 50/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.0602e-04 - val_loss: 1.9550e-05
# Epoch 51/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.9171e-04 - val_loss: 1.8239e-05
# Epoch 52/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.5966e-04 - val_loss: 2.3246e-05
# Epoch 53/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3607e-04 - val_loss: 3.0041e-05
# Epoch 54/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2508e-04 - val_loss: 4.6969e-05
# Epoch 55/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0688e-04 - val_loss: 6.5923e-05
# Epoch 56/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9400e-04 - val_loss: 8.6785e-05
# Epoch 57/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8363e-04 - val_loss: 9.5726e-05
# Epoch 58/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6951e-04 - val_loss: 1.2052e-04
# Epoch 59/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5989e-04 - val_loss: 1.5080e-04
# Epoch 60/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.4775e-04 - val_loss: 1.7143e-04
# Epoch 61/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 1.4330e-04 - val_loss: 2.0934e-04
# Epoch 62/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 1.3074e-04 - val_loss: 2.4891e-04
# Epoch 63/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.2721e-04 - val_loss: 2.8671e-04
# Epoch 64/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.1578e-04 - val_loss: 3.0876e-04
# Epoch 65/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 1.1205e-04 - val_loss: 3.2020e-04
# Epoch 66/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 1.0364e-04 - val_loss: 3.5847e-04
# Epoch 67/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 9.5998e-05 - val_loss: 3.8089e-04
# Epoch 68/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 9.0210e-05 - val_loss: 3.9340e-04
# Epoch 69/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 8.5301e-05 - val_loss: 4.2333e-04
# Epoch 70/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 8.1248e-05 - val_loss: 4.6577e-04
# Epoch 71/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 7.7140e-05 - val_loss: 5.0010e-04
# Epoch 72/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 7.7064e-05 - val_loss: 5.1071e-04
# Epoch 73/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 6.8763e-05 - val_loss: 5.2121e-04
# Epoch 74/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 6.6270e-05 - val_loss: 5.4600e-04
# Epoch 75/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 6.4655e-05 - val_loss: 5.8082e-04
# Epoch 76/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 6.0364e-05 - val_loss: 6.0728e-04
# Epoch 77/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 5.7069e-05 - val_loss: 6.1229e-04
# Epoch 78/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 5.3937e-05 - val_loss: 6.3137e-04
# Epoch 79/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 5.2203e-05 - val_loss: 6.6284e-04
# Epoch 80/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 4.9841e-05 - val_loss: 6.6582e-04
# Epoch 81/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 4.9505e-05 - val_loss: 6.8347e-04
# Epoch 82/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 4.6188e-05 - val_loss: 7.0862e-04
# Epoch 83/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 4.5018e-05 - val_loss: 7.1101e-04
# Epoch 84/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 4.1507e-05 - val_loss: 7.3414e-04
# Epoch 85/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 4.0921e-05 - val_loss: 7.5226e-04
# Epoch 86/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.8667e-05 - val_loss: 7.5500e-04
# Epoch 87/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.7898e-05 - val_loss: 7.7777e-04
# Epoch 88/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.6695e-05 - val_loss: 7.8814e-04
# Epoch 89/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.5449e-05 - val_loss: 7.8671e-04
# Epoch 90/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.4343e-05 - val_loss: 8.1199e-04
# Epoch 91/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.3812e-05 - val_loss: 8.2928e-04
# Epoch 92/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.2241e-05 - val_loss: 8.2904e-04
# Epoch 93/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.1471e-05 - val_loss: 8.4430e-04
# Epoch 94/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 3.0398e-05 - val_loss: 8.4919e-04
# Epoch 95/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.9521e-05 - val_loss: 8.6159e-04
# Epoch 96/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.8664e-05 - val_loss: 8.6874e-04
# Epoch 97/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.8383e-05 - val_loss: 8.6421e-04
# Epoch 98/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.7462e-05 - val_loss: 8.7339e-04
# Epoch 99/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.6540e-05 - val_loss: 8.8591e-04
# Epoch 100/5000
# 11/11 [==============================] - 0s 1ms/step - loss: 2.6150e-05 - val_loss: 8.9330e-04
# Epoch 101/5000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.5825e-05 - val_loss: 8.9187e-04
# 0.00040678566631995066

# %%
angles = []
for i in range(all_preds.shape[0]):
    angles.append(math.atan2(all_preds[i, 0], all_preds[i, 1]) / math.pi * 12)

for j in range(len(angles)):
    if angles[j] < 0:
        angles[j] = angles[j] + 24

ax = sn.scatterplot(Y_data[:, 0], Y_data[:, 1])
ax = sn.scatterplot(all_preds[:, 0], all_preds[:, 1])
plt.show()
angles_arr = np.vstack(angles)
hour_pred = angles_arr

plt.figure(dpi=500)
ax = sn.lineplot(np.arange(Y_copy.shape[0]), Y_copy)
ax = sn.lineplot(np.arange(Y_copy.shape[0]), angles_arr.ravel())
plt.show()


angles = []
for i in range(all_preds.shape[0]):
    angles.append(math.atan2(all_preds[i, 0], all_preds[i, 1]) / math.pi * 12)

for j in range(len(angles)):
    if angles[j] < 0:
        angles[j] = angles[j] + 24


valid_angles = []
valid_preds = np.mean(valid_preds, axis=0)
for i in range(valid_preds.shape[0]):
    valid_angles.append(math.atan2(valid_preds[i, 0], valid_preds[i, 1]) / math.pi * 12)

for j in range(len(valid_angles)):
    if valid_angles[j] < 0:
        valid_angles[j] = valid_angles[j] + 24
valid_preds = normalize(valid_preds)
ax = sn.scatterplot(Y_valid_data[:, 0], Y_valid_data[:, 1])
ax = sn.scatterplot(valid_preds[:, 0], valid_preds[:, 1])
plt.show()
angles_arr_valid = np.vstack(valid_angles)
hour_pred_valid = angles_arr_valid


plt.figure(dpi=500)
ax = sn.lineplot(np.arange(Y_valid_copy.shape[0]), Y_valid_copy)
ax = sn.lineplot(np.arange(Y_valid_copy.shape[0]), angles_arr_valid.ravel())
plt.show()

print("Average training error = {} minutes".format(60 * 12 * cyclical_loss(Y_data.astype('float64'), all_preds.astype('float64')) / (Y_data.shape[0] * np.pi)))

print("Average validation error = {} minutes".format(60 * 12 * cyclical_loss(Y_valid_data.astype('float64'), valid_preds.astype('float64')) / (Y_valid_data.shape[0] * np.pi)))

Y_copy1 = np.array([2, 5, 8, 11, 14, 17, 20, 23, 2, 5, 8, 11, 14, 17, 20, 23])

test_angles = []
test_preds_copy = test_preds
test_preds = np.mean(test_preds, axis=0)
for j in range(len(test_preds_copy)):
    for i in range(test_preds.shape[0]):
        test_preds_copy[j][i, 0] = math.atan2(test_preds_copy[j][i, 0], test_preds_copy[j][i, 1]) / math.pi * 12
        if test_preds_copy[j][i, 0] < 0:
            test_preds_copy[j][i, 0] += 24
    test_preds_copy[j] = np.delete(test_preds_copy[j], 1, 1)

for i in range(test_preds.shape[0]):
    test_angles.append(math.atan2(test_preds[i, 0], test_preds[i, 1]) / math.pi * 12)
for j in range(len(test_angles)):
    if test_angles[j] < 0:
        test_angles[j] = test_angles[j] + 24
test_preds = normalize(test_preds)
angles_arr_test = np.vstack(test_angles)
hour_pred_test = angles_arr_test
Y_test = np.array([12, 0, 12, 0])

Y_test_cos = -np.cos((2 * np.pi * Y_test.astype('float64') / 24) + (np.pi / 2))
Y_test_sin = np.sin((2 * np.pi * Y_test.astype('float64') / 24) + (np.pi / 2))
Y_test_ang = np.concatenate((Y_test_cos.reshape(-1, 1), Y_test_sin.reshape(-1, 1)), axis=1)
print("Average test error = {} minutes".format(60 * 12 * cyclical_loss(Y_test_ang.astype('float64'), test_preds.astype('float64')) / (Y_test_ang.shape[0] * np.pi)))
val_errors1.append(60 * 12 * cyclical_loss(Y_valid_data.astype('float64'), all_valid_preds.astype('float64')) / (Y_valid_data.shape[0] * np.pi))
test_errors1.append(60 * 12 * cyclical_loss(Y_test_ang.astype('float64'), test_preds.astype('float64')) / (Y_test_ang.shape[0] * np.pi))
# Out:
# C:\Users\colmer\Anaconda3\envs\dota\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\colmer\Anaconda3\envs\dota\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\colmer\Anaconda3\envs\dota\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\colmer\Anaconda3\envs\dota\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\colmer\Anaconda3\envs\dota\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\colmer\Anaconda3\envs\dota\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\colmer\Anaconda3\envs\dota\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\colmer\Anaconda3\envs\dota\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Average training error = 23.14636460828939 minutes
# Average validation error = 58.83469112670796 minutes
# Average test error = 30.85960379250752 minutes
